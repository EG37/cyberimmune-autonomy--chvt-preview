# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 3
#
# ## О документе
#
# Версия 1.03
#
# Модуль 3 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 3. Внедрение блоков функциональной и информационной безопасности
# #### Общая идея
#
# Ключевая идея кибериммунной автономности заключается в том, чтобы уже на этапе проектирования внедрить защиту от кибератак как снаружи, так и изнутри - т.е. через уязвимые бортовые информационные системы.
# Мы исходим из того, что абсолютно защищённых систем не бывает, чем больше и сложнее код, тем проще одним ("плохим") в нём спрятать уязвимости, а другим ("хорошим", но уставшим) эти уязвимости не найти.
#
# Поэтому необходимо сделать так, чтобы наиболее критичный код был отделён от некритичного и протестирован особенно тщательно - таким образом можно снизить вероятность успешной атаки и затруднить задачу атакующим.

# %% [markdown]
# #### Цели и предположения безопасности
#
# ##### Цели безопасности
# Устойчивость кибериммунных систем к атакам выражается в том, что поставленные заказчиком **цели безопасности** (ЦБ) не нарушаются даже в условиях кибератак (снаружи и изнутри).
#
# Для наших автономных машинок заказчиком поставлены следующие ЦБ:
#
# 1. При любых обстоятельствах АНТС осуществляет перемещения в пределах заданных ограничений
#
# 2. При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут
#
# 3. При любых обстоятельствах АНТС оставляет груз только в авторизованном пункте назначения
#
# Ниже используется цифро-буквенное обозначение целей безопасности - например, ЦБ1 - первая цель безопасности из списка выше.
#
# ##### Предположения безопасности
# При этом заказчик согласовал с разработчиками следующие **предположения безопасности** (ПБ) - утверждения о смежных системах, которые снимают с разработчиков часть задач для обеспечения целей безопасности:
#
# 1. При любых обстоятельствах только авторизованный персонал имеет физический доступ к критическим узлам АНТС
#
# 2. При любых обстоятельствах только аутентичные и авторизованные операторы имеют доступ к системе планирования заданий
#
# 3. Аутентичные и авторизованные операторы обладают необходимой квалификацией и являются благонадёжными (т.е. не пытаются намеренно причинить ущерб системе или третьим лицам, используя доступ к АНТС)
#
# Ниже используется цифро-буквенное обозначение предположений безопасности - например, ПБ1 - первое предположение безопасности из списка выше.

# %% [markdown]
# ### Киберпрепятствия
#
# Прежде чем мы начнём внедрять механизмы безопасности, посмотрим, что произойдёт с нашей машинкой, если бортовые системы начнут вести себя не так, как мы ожидаем.
#
# Для этого активируем специальный режим работы системы управления и снова запустим машинку по тому же маршруту, который был в конце модуля 2.
#
# После инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# Но вначале нужно из модуля 2 скопировать сюда ваши текущие наработки, а именно ваши реализации классов коммуникационного шлюза (CommunicationGateway), систему навигации (NavigationSystem), управления (ControlSystem), также будем использовать маршрут, который вы создали.

# %%
from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.event_types import Event

class CommunicationGateway(BaseCommunicationGateway):
    """Коммуникационный шлюз"""
    def _send_mission_to_consumers(self):
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME

        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)


class ControlSystem(BaseControlSystem):
    """Система управления"""
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=servos_q_name,
                      operation="set_speed", parameters=speed
                      )

        event_direction = Event(source=BaseControlSystem.event_source_name,
                          destination=servos_q_name,
                          operation="set_direction", parameters=direction
                          )

        servos_q.put(event_speed)
        servos_q.put(event_direction)
    
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=CARGO_BAY_QUEUE_NAME,
                      operation="lock_cargo",
                      parameters=None
                      )
        cargo_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=CARGO_BAY_QUEUE_NAME,
                      operation="release_cargo",
                      parameters=None
                      )
        cargo_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """Система навигации"""
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseNavigationSystem.event_source_name,
                          destination=control_q_name,
                          operation="position_update", parameters=self._position
                          )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m3"

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "svetofor.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(2, 60),
    GeoSpecificSpeedLimit(8, 20),
]

home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

# по аналогии собираем все блоки в одном кузове
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# ограничение поездки по времени
# параметр sleep - время в секундах,
# настройте этот параметр так, чтобы ваша машинка завершила маршрут
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(135)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
del system_components
# Out:
# [Point(59.88311038619264, 29.834416819899282, 0.0), Point(59.88316739379213, 29.83410271042786, 0.0), Point(59.88292618713636, 29.833918984178702, 0.0), Point(59.884406447511914, 29.82718191038223, 0.0), Point(59.882409426144, 29.827965041591245, 0.0), Point(59.88192495544521, 29.827439378202076, 0.0), Point(59.88111210540939, 29.826849347867295, 0.0), Point(59.878027400845845, 29.82401720196725, 0.0), Point(59.87664497445017, 29.830429915603762, 0.0), Point(59.87634313737615, 29.830001068799085, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 14:09:17.474574
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 289 (было 0)
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 26 (было 289)
# [ИНФО][CONTROL] новое направление 20 (было 26)
# [ИНФО][CONTROL] новое направление 15 (было 20)
# [ИНФО][CONTROL] новое направление 16 (было 15)

# %% [markdown]
# Итак, в отличие от, надеемся, успешного завершения маршрута в модуле 2, сейчас ваша машинка ведёт себя совсем иначе. Например, она внезапно едет в совершенно другую сторону (это особенно хорошо видно при использовании СУПА).
# И это ещё не всё, что может пойти не так..
#
# В этой реализации не очень много кода, теоретически, вы можете его весь изучить и устранить "незадокументированные возможности", однако в реальных системах кода гораздо больше. Например, кодовая база проекта с открытым исходным кодом ArduPilot, реализующего в том числе логику автопилота, составляет примерно миллион строк.
#
# Сколько времени вам понадобится, чтобы изучить и протестировать миллион строк кода? А ведь придётся проводить анализ и каждого обновления.. При этом неприятности могут быть хорошо спрятанными и на первый взгляд безобидными, вряд ли злоумышленники облегчат задачу и назовут свои изменения, например, "hacking_the_system" или "allowing_secret_remote_access". Вредоносный код может выглядеть совершенно безобидно или маскироваться под программный дефект.
#
# Поэтому тщательный анализ потребует большого количества ресурсов (человеческих, вычислительных, временныз), что стоит дорого.
#
# Логичным выходом является выделение критичных для целей безопасности проверок в отдельный блок, который протестировать должно быть гораздо проще.

# %% [markdown]
# #### Задания
#
# В этом модуле задание будет состоять из двух частей разной сложности:
#
# **3.1. добавить новый блок - "Ограничитель"** - этот модуль должен будет обеспечить соблюдение ограничений, указанных в маршрутном задании - это необходимо для обеспечения ЦБ1
#
# **З.2. *(задание повышенной сложности)* добавить монитор безопасности (МБ)** - он должен контролировать все взаимодействия *бортовых систем* (т.е. не включая планировщик и симулятор) и не давать блокам взаимодействовать друг с другом непредусмотренным образом - например, блок №5 может принимать команды только от №3, попытка передать команду в №5 от №2 должна блокироваться нашим монитором безопасности - потенциально это необходимо для обеспечения всех ЦБ

# %% [markdown]
# Для выполнения первой части задачи 3.1. необходимо для начала изменить архитектуру АНТС как показано на рис. 5
#
# ![Архитектура системы с ограничителем](images/ciac-arch-m31.png)
#
# Рис. 5. Архитектура АНТС с ограничителем (для ЦБ1)

# %% [markdown]
# Код базового класса Ограничителя находится в файле src/safety_block.py
#
# По аналогии с заданием в модуле 1, необходимо создать на основе этого класса свой собственный под названием SafetyBlock, в котором реализовать передачу команд в приводы движения, только перед эти необходимо ещё и проконтролировать их безопасность.
#
# Также необходимо реализовать передачу маршрутного задания из CommunicationGateway в SafetyBlock и координат из модуля Navigation в соответствии со стрелками на рис.5 выше.
#
# Если всё сделано правильно, то Ограничителю будет известно следующее
#
# - _mission - текущее маршрутное задание
# - _position - текущие координаты
#
# После проверки нужно установить значение внутренних переменных
# - _speed - текущая (допустимая) скорость
# - _direction - текущее (допустимое) направление
#
# Желательно завершить следование по маршруту. В критической ситуации, если продолжение маршрута невозможно, следует установить значение скорости и направления в 0, после чего передать эти команды в блок приводов (Servos)

# %% [markdown]
# Базовый сценарий для новой архитектуры можно представить следующим образом (см. рис. 6)
#
# ![Базовый сценарий с блоком безопасности](images/basic-scenario-with-safety-block1.png)
#
# Рис. 6. Базовый сценарий с блоком безопасности

# %% [markdown]
# Заготовка кода SafetyBlock
#
# ```python
# class SafetyBlock(BaseSafetyBlock):
#     """ класс ограничений безопасности """
#
#     def _set_new_direction(self, direction: float):
#         """ установка нового направления перемещения """
#         self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
#         self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
#         self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
#         # TODO реализовать контроль безопасности изменения направления
#         self._direction = direction
#         self._send_direction_to_consumers()
#
#     def _set_new_speed(self, speed: float):
#         """ установка новой скорости """
#         # TODO реализовать контроль безопасности изменения скорости
#         self._speed = speed
#         self._send_speed_to_consumers()
#
#
#     def _send_speed_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем скорость получателям")
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_speed",
#                             parameters=self._speed
#                             )
#         servos_q.put(event_speed)
#
#     def _send_direction_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем направление получателям")
#
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_direction",
#                             parameters=self._direction
#                             )
#         servos_q.put(event_speed)
# ```

# %%
from src.safety_block import BaseSafetyBlock
from src.config import LOG_FAILURE, LOG_DEBUG
from math import radians, sin, cos, degrees, atan2


# 1. скопируйте сюда код заготовки из предыдущей ячейки и напишите свою реализацию класса SafetyBlock
class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _emergency_stop(self):
        """Аварийная остановка"""
        # Устанавливаем скорость на 0
        self._speed = 0
        self._direction = 0
        
        # Записываем в лог сообщение об остановке и сообщаем координаты
        self._log_message(LOG_FAILURE, f'Произошла аварийная остановка. Текущие координаты: {self._position}.')
    
    def _calculate_direction(self):
        """Вычисляем направление движения к следующей точке маршрута"""
        if not self._route.next_point():
            # Предусмотрим нахождение в последней точке маршрута
            return self._direction
        cur_lat = radians(self._position.latitude)
        dest_lat = radians(self._route.next_point().latitude)
        long = radians(self._route.next_point().longitude - self._position.longitude)

        x = sin(long) * cos(dest_lat)
        y = cos(cur_lat) * sin(dest_lat) - sin(cur_lat) * cos(dest_lat) * cos(long)

        return (degrees(atan2(x, y)) + 360) % 360

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        
        # Если новое направление отличается от правильного по модулю более чем на 1 градус, не разрешаем изменение
        waypoint_direction = self._calculate_direction()
        if (abs(waypoint_direction - direction) >= 1):
            self._log_message(LOG_ERROR, f'Заданное направление {direction} отличается от верного.')
            self._direction = waypoint_direction
            self._send_direction_to_consumers()
            return

        self._direction = direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        
        # Находим ограничение по скорости
        speed_limit = self._route.calculate_speed()

        # Проверяем соответствие нового значения ограничениям
        if speed > speed_limit:
            # В случае некорректного значения не меняем скорость
            self._log_message(LOG_ERROR, f'Заданная скорость {speed} превышает ограничение {speed_limit}.')
        else:
            # В случае корректрного значения устанавливаем новую скорость
            self._speed = speed
        # Отправляем сообщение с новым значением скорости
        self._send_speed_to_consumers()


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)
    
    def _lock_cargo(self, _):
        # Передаем сообщения
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._log_message(LOG_DEBUG, "Передана команда на блокировку грузового отсека")

        cargo_q_name = CARGO_BAY_QUEUE_NAME

        event = Event(source=self.event_source_name,
                      destination=cargo_q_name,
                      operation="lock_cargo",
                      parameters=None
                      )
        
        cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)
        cargo_q.put(event)
    
    def _release_cargo(self, _):
        # Передаем сообщения
        self._log_message(LOG_DEBUG, "Передана команда на разблокировку грузового отсека")

        if self._route.route_finished:
            cargo_q_name = CARGO_BAY_QUEUE_NAME

            event = Event(source=self.event_source_name,
                        destination=cargo_q_name,
                        operation="release_cargo",
                        parameters=None
                        )
            
            cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)
            cargo_q.put(event)

            self._log_message(LOG_INFO, "Разблокирован грузовой отсек")
        else:
            self._log_message(LOG_DEBUG, "Маршрут не пройден, отказано в разблокировке грузового отсека.")

# %%
# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# 3. создайте экземпляры изменённых классов и отправьте машинку по ранее предложенному маршруту


from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.event_types import Event

class CommunicationGateway(BaseCommunicationGateway):
    """Коммуникационный шлюз"""
    def _send_mission_to_consumers(self):
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        control_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(control_event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


class ControlSystem(BaseControlSystem):
    """Система управления"""
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        # Добавим создание очереди безопасности
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # Заменим destination на очередь безопасности
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                      )

        event_direction = Event(source=BaseControlSystem.event_source_name,
                          destination=safety_q_name,
                          operation="set_direction", parameters=direction
                          )

        # Положим события в очередь
        safety_q.put(event_speed)
        safety_q.put(event_direction)
    
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """

        # Добавим очередь безопасности для выполнения ЦБ
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=safety_q_name,
                      operation="lock_cargo",
                      parameters=None
                      )
        
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """

        # Добавим очередь безопасности для выполнения ЦБ
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=safety_q_name,
                      operation="release_cargo",
                      parameters=None
                      )
        
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

class NavigationSystem(BaseNavigationSystem):
    """Система навигации"""
    def _send_position_to_consumers(self):        
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        event = Event(source=BaseNavigationSystem.event_source_name,
                          destination=control_q_name,
                          operation="position_update", parameters=self._position
                          )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


# Создаем экземпляры измененных классов
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
# Out:
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь communication

# %%
# создадим все остальные компоненты

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)
# Out:
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель

# %%
# соберём все компоненты для запуска

# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(200)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2279s N, 29 50m 3.73262s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2585s N, 29 50m 3.56468s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.289s N, 29 50m 3.39675s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3134s N, 29 50m 3.2624s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3439s N, 29 50m 3.09445s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3744s N, 29 50m 2.92649s E
# [ОШИБКА][SAFETY] Заданное направление 26.0419055927498 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4049s N, 29 50m 2.75852s E
# [ОШИБКА][SAFETY] Заданное направление 20.54214744793262 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4353s N, 29 50m 2.59051s E
# [ОШИБКА][SAFETY] Заданное направление 15.029905281788956 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3547s N, 29 50m 2.51211s E
# [ОШИБКА][SAFETY] Заданное направление 13.8716885816807 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2706s N, 29 50m 2.44944s E
# [ОШИБКА][SAFETY] Заданное направление 13.085359081984052 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1839s N, 29 50m 2.40313s E
# [ОШИБКА][SAFETY] Заданное направление 12.826737712357499 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0968s N, 29 50m 2.36032s E
# [ОШИБКА][SAFETY] Заданное направление 12.667586458345284 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0094s N, 29 50m 2.31989s E
# [ОШИБКА][SAFETY] Заданное направление 12.594498384690496 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9218s N, 29 50m 2.28024s E
# [ОШИБКА][SAFETY] Заданное направление 12.546740676482443 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8343s N, 29 50m 2.24108s E
# [ОШИБКА][SAFETY] Заданное направление 12.517500523909916 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7467s N, 29 50m 2.20214s E
# [ОШИБКА][SAFETY] Заданное направление 12.494244709173017 отличается от верного.
# [ИНФО][SAFETY] сегмент пройден
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6591s N, 29 50m 2.16334s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5714s N, 29 50m 2.12464s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.4838s N, 29 50m 2.08601s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.519s N, 29 50m 1.92175s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5548s N, 29 50m 1.75797s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5911s N, 29 50m 1.59467s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6275s N, 29 50m 1.43137s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6638s N, 29 50m 1.26807s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7001s N, 29 50m 1.10477s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7364s N, 29 50m 0.941475s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7728s N, 29 50m 0.778177s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8091s N, 29 50m 0.614878s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8454s N, 29 50m 0.451579s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8818s N, 29 50m 0.288279s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9181s N, 29 50m 0.124979s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9544s N, 29 49m 59.9617s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9908s N, 29 49m 59.7984s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0271s N, 29 49m 59.6351s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0634s N, 29 49m 59.4718s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0997s N, 29 49m 59.3085s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1361s N, 29 49m 59.1452s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1724s N, 29 49m 58.9819s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2087s N, 29 49m 58.8186s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.245s N, 29 49m 58.6553s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2814s N, 29 49m 58.492s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3177s N, 29 49m 58.3287s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.354s N, 29 49m 58.1653s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3903s N, 29 49m 58.002s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4267s N, 29 49m 57.8387s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.463s N, 29 49m 57.6754s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4993s N, 29 49m 57.5121s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.5356s N, 29 49m 57.3488s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.572s N, 29 49m 57.1855s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6083s N, 29 49m 57.0222s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6446s N, 29 49m 56.8589s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6809s N, 29 49m 56.6956s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.7172s N, 29 49m 56.5323s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.7463s N, 29 49m 56.4016s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.7826s N, 29 49m 56.2383s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.8189s N, 29 49m 56.075s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.8552s N, 29 49m 55.9117s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.8916s N, 29 49m 55.7484s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.9279s N, 29 49m 55.5851s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.9642s N, 29 49m 55.4217s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.000503307s N, 29 49m 55.2584s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.0368178s N, 29 49m 55.0951s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.0731318s N, 29 49m 54.9318s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.109445s N, 29 49m 54.7685s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.145758s N, 29 49m 54.6052s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.182071s N, 29 49m 54.4419s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.218382s N, 29 49m 54.2785s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.254693s N, 29 49m 54.1152s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.291004s N, 29 49m 53.9519s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.327314s N, 29 49m 53.7886s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.363624s N, 29 49m 53.6253s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.399932s N, 29 49m 53.4619s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.436241s N, 29 49m 53.2986s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.472548s N, 29 49m 53.1353s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.508855s N, 29 49m 52.972s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.545162s N, 29 49m 52.8087s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.581468s N, 29 49m 52.6453s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.617773s N, 29 49m 52.482s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.654077s N, 29 49m 52.3187s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.690381s N, 29 49m 52.1554s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.726685s N, 29 49m 51.992s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.762987s N, 29 49m 51.8287s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.799289s N, 29 49m 51.6654s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.835591s N, 29 49m 51.5021s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.871891s N, 29 49m 51.3387s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.908191s N, 29 49m 51.1754s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.94449s N, 29 49m 51.0121s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.980789s N, 29 49m 50.8487s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.01709s N, 29 49m 50.6854s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.05338s N, 29 49m 50.5221s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.08968s N, 29 49m 50.3587s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.12598s N, 29 49m 50.1954s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.16227s N, 29 49m 50.0321s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.19857s N, 29 49m 49.8687s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.23486s N, 29 49m 49.7054s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.27115s N, 29 49m 49.5421s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.30744s N, 29 49m 49.3787s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.34373s N, 29 49m 49.2154s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.38002s N, 29 49m 49.0521s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.41631s N, 29 49m 48.8887s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.44535s N, 29 49m 48.7581s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.48163s N, 29 49m 48.5947s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.51792s N, 29 49m 48.4314s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.55421s N, 29 49m 48.268s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.59049s N, 29 49m 48.1047s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.62678s N, 29 49m 47.9413s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.66306s N, 29 49m 47.778s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.69934s N, 29 49m 47.6147s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.73563s N, 29 49m 47.4513s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.77191s N, 29 49m 47.288s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.80819s N, 29 49m 47.1246s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.84447s N, 29 49m 46.9613s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.88075s N, 29 49m 46.7979s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.91703s N, 29 49m 46.6346s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.9533s N, 29 49m 46.4712s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.98958s N, 29 49m 46.3079s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.02585s N, 29 49m 46.1445s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.06213s N, 29 49m 45.9812s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.0984s N, 29 49m 45.8178s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.13467s N, 29 49m 45.6545s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.17094s N, 29 49m 45.4911s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.20721s N, 29 49m 45.3277s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.24348s N, 29 49m 45.1644s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.27974s N, 29 49m 45.001s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.31601s N, 29 49m 44.8377s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.35227s N, 29 49m 44.6743s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.38853s N, 29 49m 44.5109s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.42479s N, 29 49m 44.3476s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.46105s N, 29 49m 44.1842s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.49731s N, 29 49m 44.0208s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.53357s N, 29 49m 43.8575s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.56982s N, 29 49m 43.6941s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.60608s N, 29 49m 43.5307s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.64233s N, 29 49m 43.3674s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.67858s N, 29 49m 43.204s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.71483s N, 29 49m 43.0406s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.75107s N, 29 49m 42.8772s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.78732s N, 29 49m 42.7138s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.82356s N, 29 49m 42.5505s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.8598s N, 29 49m 42.3871s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.89604s N, 29 49m 42.2237s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.93228s N, 29 49m 42.0603s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.96852s N, 29 49m 41.8969s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.00475s N, 29 49m 41.7335s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.04098s N, 29 49m 41.5701s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.07721s N, 29 49m 41.4067s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.11344s N, 29 49m 41.2433s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.14242s N, 29 49m 41.1126s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.17864s N, 29 49m 40.9492s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.21486s N, 29 49m 40.7858s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.25107s N, 29 49m 40.6224s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.28729s N, 29 49m 40.459s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.3235s N, 29 49m 40.2956s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.3597s N, 29 49m 40.1322s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.39591s N, 29 49m 39.9688s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.43211s N, 29 49m 39.8054s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.4683s N, 29 49m 39.6419s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.50449s N, 29 49m 39.4785s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.54067s N, 29 49m 39.3151s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.57685s N, 29 49m 39.1516s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.61303s N, 29 49m 38.9882s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.64919s N, 29 49m 38.8247s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.68535s N, 29 49m 38.6613s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.7215s N, 29 49m 38.4978s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.75763s N, 29 49m 38.3343s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.79375s N, 29 49m 38.1708s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.82986s N, 29 49m 38.0073s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.86593s N, 29 49m 37.8438s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.90195s N, 29 49m 37.6802s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.63726s N, 29 49m 37.7787s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.37309s N, 29 49m 37.8825s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.10945s N, 29 49m 37.9915s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.84585s N, 29 49m 38.1009s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.58227s N, 29 49m 38.2106s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.3187s N, 29 49m 38.3203s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.05513s N, 29 49m 38.43s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.79157s N, 29 49m 38.5397s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.528s N, 29 49m 38.6494s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.26443s N, 29 49m 38.7592s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.00087s N, 29 49m 38.8689s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.737303s N, 29 49m 38.9787s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.47374s N, 29 49m 39.0884s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.210179s N, 29 49m 39.1982s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.9466s N, 29 49m 39.308s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6831s N, 29 49m 39.4178s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4195s N, 29 49m 39.5276s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1559s N, 29 49m 39.6375s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8924s N, 29 49m 39.7473s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6288s N, 29 49m 39.8572s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.3653s N, 29 49m 39.9671s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.1017s N, 29 49m 40.077s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.8382s N, 29 49m 40.187s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.5747s N, 29 49m 40.2969s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.3111s N, 29 49m 40.407s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.1003s N, 29 49m 40.495s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.8368s N, 29 49m 40.6052s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.5733s N, 29 49m 40.7155s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.3098s N, 29 49m 40.826s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.0464s N, 29 49m 40.9373s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.8145s N, 29 49m 40.665s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.5984s N, 29 49m 40.3454s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.405s N, 29 49m 39.9726s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.221s N, 29 49m 39.5815s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.0463s N, 29 49m 39.1738s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8787s N, 29 49m 38.7544s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7206s N, 29 49m 38.3208s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5834s N, 29 49m 37.8599s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3305s N, 29 49m 37.6757s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0731s N, 29 49m 37.5184s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8109s N, 29 49m 37.3965s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5479s N, 29 49m 37.2816s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.2843s N, 29 49m 37.1721s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.0205s N, 29 49m 37.0645s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.7566s N, 29 49m 36.958s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.4927s N, 29 49m 36.8522s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.2286s N, 29 49m 36.7467s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.9646s N, 29 49m 36.6416s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.7005s N, 29 49m 36.5367s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.4364s N, 29 49m 36.4324s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.1919s N, 29 49m 36.2078s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.9481s N, 29 49m 35.9807s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.7048s N, 29 49m 35.751s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.4616s N, 29 49m 35.521s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.2184s N, 29 49m 35.2911s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.9752s N, 29 49m 35.0611s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.732s N, 29 49m 34.831s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.4888s N, 29 49m 34.601s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.2456s N, 29 49m 34.371s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.0025s N, 29 49m 34.141s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.7593s N, 29 49m 33.9109s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.5161s N, 29 49m 33.6809s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.2729s N, 29 49m 33.4508s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.0297s N, 29 49m 33.2208s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.7866s N, 29 49m 32.9907s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.5434s N, 29 49m 32.7606s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.3002s N, 29 49m 32.5305s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.0571s N, 29 49m 32.3004s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.8139s N, 29 49m 32.0703s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.5707s N, 29 49m 31.8401s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.3276s N, 29 49m 31.61s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.1331s N, 29 49m 31.4259s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.8899s N, 29 49m 31.1957s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.6468s N, 29 49m 30.9655s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.4036s N, 29 49m 30.7353s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.1605s N, 29 49m 30.5051s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.9173s N, 29 49m 30.2749s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.6742s N, 29 49m 30.0447s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.4311s N, 29 49m 29.8144s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.1879s N, 29 49m 29.5841s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.9448s N, 29 49m 29.3538s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.7017s N, 29 49m 29.1235s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.4586s N, 29 49m 28.8932s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.2155s N, 29 49m 28.6628s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.9724s N, 29 49m 28.4324s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.7293s N, 29 49m 28.202s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.4862s N, 29 49m 27.9715s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.2432s N, 29 49m 27.741s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.0001s N, 29 49m 27.5104s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.7571s N, 29 49m 27.2798s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.514s N, 29 49m 27.0491s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.271s N, 29 49m 26.8183s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.0281s N, 29 49m 26.5874s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.7851s N, 29 49m 26.3564s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5423s N, 29 49m 26.125s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2995s N, 29 49m 25.8931s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1957s N, 29 49m 26.3874s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0972s N, 29 49m 26.8859s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0041s N, 29 49m 27.3885s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9112s N, 29 49m 27.8912s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8184s N, 29 49m 28.3941s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7256s N, 29 49m 28.897s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6328s N, 29 49m 29.3998s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.54s N, 29 49m 29.9027s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4473s N, 29 49m 30.4056s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3545s N, 29 49m 30.9084s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2618s N, 29 49m 31.4113s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.169s N, 29 49m 31.9142s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0762s N, 29 49m 32.417s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9835s N, 29 49m 32.9199s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8907s N, 29 49m 33.4228s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.798s N, 29 49m 33.9257s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7053s N, 29 49m 34.4286s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6125s N, 29 49m 34.9314s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5198s N, 29 49m 35.4343s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4456s N, 29 49m 35.8366s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3529s N, 29 49m 36.3395s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2602s N, 29 49m 36.8424s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1675s N, 29 49m 37.3453s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0748s N, 29 49m 37.8482s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.982s N, 29 49m 38.3511s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8893s N, 29 49m 38.8541s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7967s N, 29 49m 39.357s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.704s N, 29 49m 39.8599s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6113s N, 29 49m 40.3628s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5186s N, 29 49m 40.8657s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.426s N, 29 49m 41.3687s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3333s N, 29 49m 41.8716s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2406s N, 29 49m 42.3746s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.148s N, 29 49m 42.8775s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0554s N, 29 49m 43.3805s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9628s N, 29 49m 43.8834s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8702s N, 29 49m 44.3864s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.7776s N, 29 49m 44.8894s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.685s N, 29 49m 45.3924s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.5924s N, 29 49m 45.8954s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4999s N, 29 49m 46.3984s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4073s N, 29 49m 46.9014s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3148s N, 29 49m 47.4045s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.2224s N, 29 49m 47.9075s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.1299s N, 29 49m 48.4106s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0375s N, 29 49m 48.9137s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9452s N, 29 49m 49.4169s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.853s N, 29 49m 49.9202s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.761s N, 29 49m 50.4236s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6854s N, 29 49m 50.3275s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6201s N, 29 49m 50.2048s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5657s N, 29 49m 50.0628s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5129s N, 29 49m 49.9186s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4609s N, 29 49m 49.773s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4091s N, 29 49m 49.6272s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3573s N, 29 49m 49.4813s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3056s N, 29 49m 49.3353s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.254s N, 29 49m 49.1893s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2023s N, 29 49m 49.0434s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.1506s N, 29 49m 48.8974s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.099s N, 29 49m 48.7513s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0473s N, 29 49m 48.6053s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9957s N, 29 49m 48.4592s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9441s N, 29 49m 48.3132s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Разблокирован грузовой отсек
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.8925s N, 29 49m 48.1671s E
# [ОШИБКА][SAFETY] Заданное направление 0.0 отличается от верного.
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# #### Обеспечение ЦБ3: контроль доставки груза
#
# С помощью логики ограничителя выше мы реализовали обеспечение ЦБ1 (соблюдение заданных ограничений), однако есть ещё ЦБ3 (отгрузка только в заданной точке), не говоря о ЦБ2 (следование только по аутентичному маршруту).
#
# Для обеспечения ЦБ3 необходимо сделать следующее
# 1. изменить последовательность передачи команд, чтобы в блок управления грузовым отсеком (CargoBay) команды приходили только после проверки в Ограничителе
# 2. доработайте реализацию Ограничителя, чтобы команда на выгрузку передавалась в CargoBay только в конечной точке маршрута
# 3. продумайте логику работы блока безопасности, если система управления полностью перестанет работать (т.е. перестанет отправлять новые команды).
#
# Изменённая архитектура приведена на рис. 7.
#
# ![Ограничитель для обеспечения ЦБ1 и ЦБ3](images/ciac-arch-m312.png)
#
# Рис. 7. Ограничитель для обеспечения ЦБ1 и ЦБ3

# %%
# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку

# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# 3. создайте экземпляры изменённых классов и отправьте машинку по ранее предложенному маршруту


from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.event_types import Event

class CommunicationGateway(BaseCommunicationGateway):
    """Коммуникационный шлюз"""
    def _send_mission_to_consumers(self):
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        control_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(control_event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


class ControlSystem(BaseControlSystem):
    """Система управления"""
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        # Добавим создание очереди безопасности
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # Заменим destination на очередь безопасности
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                      )

        event_direction = Event(source=BaseControlSystem.event_source_name,
                          destination=safety_q_name,
                          operation="set_direction", parameters=direction
                          )

        # Положим события в очередь
        safety_q.put(event_speed)
        safety_q.put(event_direction)
    
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """

        # Добавим очередь безопасности для выполнения ЦБ
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=safety_q_name,
                      operation="lock_cargo",
                      parameters=None
                      )
        
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """

        # Добавим очередь безопасности для выполнения ЦБ
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=safety_q_name,
                      operation="release_cargo",
                      parameters=None
                      )
        
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

class NavigationSystem(BaseNavigationSystem):
    """Система навигации"""
    def _send_position_to_consumers(self):        
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        event = Event(source=BaseNavigationSystem.event_source_name,
                          destination=control_q_name,
                          operation="position_update", parameters=self._position
                          )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


# Создаем экземпляры измененных классов
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _emergency_stop(self):
        """Аварийная остановка"""
        # Устанавливаем скорость на 0
        self._speed = 0
        self._direction = 0
        
        # Записываем в лог сообщение об остановке и сообщаем координаты
        self._log_message(LOG_FAILURE, f'Произошла аварийная остановка. Текущие координаты: {self._position}.')
    
    def _calculate_direction(self):
        """Вычисляем направление движения к следующей точке маршрута"""
        if not self._route.next_point():
            # Предусмотрим нахождение в последней точке маршрута
            return self._direction
        cur_lat = radians(self._position.latitude)
        dest_lat = radians(self._route.next_point().latitude)
        long = radians(self._route.next_point().longitude - self._position.longitude)

        x = sin(long) * cos(dest_lat)
        y = cos(cur_lat) * sin(dest_lat) - sin(cur_lat) * cos(dest_lat) * cos(long)

        return (degrees(atan2(x, y)) + 360) % 360

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        
        # Если новое направление отличается от правильного по модулю более чем на 1 градус, не разрешаем изменение
        waypoint_direction = self._calculate_direction()
        if (abs(waypoint_direction - direction) >= 1):
            self._log_message(LOG_ERROR, f'Заданное направление {direction} отличается от верного.')
            self._direction = waypoint_direction
            self._send_direction_to_consumers()
            return

        self._direction = direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        
        # Находим ограничение по скорости
        speed_limit = self._route.calculate_speed()

        # Проверяем соответствие нового значения ограничениям
        if speed > speed_limit:
            # В случае некорректного значения не меняем скорость
            self._log_message(LOG_ERROR, f'Заданная скорость {speed} превышает ограничение {speed_limit}.')
        else:
            # В случае корректрного значения устанавливаем новую скорость
            self._speed = speed
        # Отправляем сообщение с новым значением скорости
        self._send_speed_to_consumers()


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)
    
    def _lock_cargo(self, _):
        # Передаем сообщения
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._log_message(LOG_DEBUG, "Передана команда на блокировку грузового отсека")

        cargo_q_name = CARGO_BAY_QUEUE_NAME

        event = Event(source=self.event_source_name,
                      destination=cargo_q_name,
                      operation="lock_cargo",
                      parameters=None
                      )
        
        cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)
        cargo_q.put(event)
    
    def _release_cargo(self, _):
        # Передаем сообщения
        self._log_message(LOG_DEBUG, "Передана команда на разблокировку грузового отсека")

        if self._route.route_finished:
            cargo_q_name = CARGO_BAY_QUEUE_NAME

            event = Event(source=self.event_source_name,
                        destination=cargo_q_name,
                        operation="release_cargo",
                        parameters=None
                        )
            
            cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)
            cargo_q.put(event)

            self._log_message(LOG_INFO, "Разблокирован грузовой отсек")
        else:
            self._log_message(LOG_DEBUG, "Маршрут не пройден, отказано в разблокировке грузового отсека.")


from time import sleep

from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser
from src.mission_type import GeoSpecificSpeedLimit


# возьмём маршрут из модуля 2
wpl_file = "svetofor.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()

# обновите скоростные ограничения для вашего маршрута!
speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(2, 60),
    GeoSpecificSpeedLimit(8, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 


# создание блоков передачи данных в СУПА
if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

# создание основных функциональных блоков
mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)     
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)


# сборка всех запускаемых блоков в одном "кузове"
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

# запуск всех блоков
system_components.start()

# ограничение поездки по времени
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(200)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 14:14:55.171866
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 289 (было 0)
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2279s N, 29 50m 3.73262s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2585s N, 29 50m 3.56468s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2829s N, 29 50m 3.43034s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3134s N, 29 50m 3.2624s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3439s N, 29 50m 3.09445s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 26 (было 289)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3744s N, 29 50m 2.92649s E
# [ОШИБКА][SAFETY] Заданное направление 26.041900543079237 отличается от верного.
# [ИНФО][CONTROL] новое направление 20 (было 26)
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4049s N, 29 50m 2.75852s E
# [ОШИБКА][SAFETY] Заданное направление 20.54214684788269 отличается от верного.
# [ИНФО][CONTROL] новое направление 15 (было 20)
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4353s N, 29 50m 2.59051s E
# [ОШИБКА][SAFETY] Заданное направление 15.029909162371155 отличается от верного.
# [ИНФО][CONTROL] новое направление 13 (было 15)
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3547s N, 29 50m 2.51211s E
# [ОШИБКА][SAFETY] Заданное направление 13.871694425096337 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2706s N, 29 50m 2.44944s E
# [ОШИБКА][SAFETY] Заданное направление 13.085366466681648 отличается от верного.
# [ИНФО][CONTROL] новое направление 12 (было 13)
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1839s N, 29 50m 2.40313s E
# [ОШИБКА][SAFETY] Заданное направление 12.826745860104893 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0968s N, 29 50m 2.36032s E
# [ОШИБКА][SAFETY] Заданное направление 12.667595171282073 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0094s N, 29 50m 2.31989s E
# [ОШИБКА][SAFETY] Заданное направление 12.594507456024076 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9218s N, 29 50m 2.28024s E
# [ОШИБКА][SAFETY] Заданное направление 12.546750051026947 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8343s N, 29 50m 2.24108s E
# [ОШИБКА][SAFETY] Заданное направление 12.517510169129594 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7467s N, 29 50m 2.20214s E
# [ОШИБКА][SAFETY] Заданное направление 12.494254677046627 отличается от верного.
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 160 (была 20)
# [ИНФО][CONTROL] новое направление 293 (было 12)
# [ИНФО][SAFETY] сегмент пройден
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6591s N, 29 50m 2.16335s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5714s N, 29 50m 2.12464s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.4838s N, 29 50m 2.08601s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.519s N, 29 50m 1.92175s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5548s N, 29 50m 1.75797s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5911s N, 29 50m 1.59467s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6275s N, 29 50m 1.43137s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6638s N, 29 50m 1.26807s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7001s N, 29 50m 1.10477s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7364s N, 29 50m 0.941475s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7728s N, 29 50m 0.778177s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8091s N, 29 50m 0.614878s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8454s N, 29 50m 0.451579s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8818s N, 29 50m 0.28828s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9181s N, 29 50m 0.12498s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9544s N, 29 49m 59.9617s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9908s N, 29 49m 59.7984s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0271s N, 29 49m 59.6351s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0634s N, 29 49m 59.4718s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0997s N, 29 49m 59.3085s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1361s N, 29 49m 59.1452s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1724s N, 29 49m 58.9819s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2087s N, 29 49m 58.8186s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.245s N, 29 49m 58.6553s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2814s N, 29 49m 58.492s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3177s N, 29 49m 58.3287s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.354s N, 29 49m 58.1653s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3903s N, 29 49m 58.002s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4267s N, 29 49m 57.8387s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.463s N, 29 49m 57.6754s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4993s N, 29 49m 57.5121s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.5356s N, 29 49m 57.3488s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.572s N, 29 49m 57.1855s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6083s N, 29 49m 57.0222s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6446s N, 29 49m 56.8589s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6736s N, 29 49m 56.7282s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.71s N, 29 49m 56.5649s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.7463s N, 29 49m 56.4016s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.7826s N, 29 49m 56.2383s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.8189s N, 29 49m 56.075s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.8552s N, 29 49m 55.9117s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.8916s N, 29 49m 55.7484s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.9279s N, 29 49m 55.5851s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.9642s N, 29 49m 55.4217s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.000503953s N, 29 49m 55.2584s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.0368185s N, 29 49m 55.0951s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.0731325s N, 29 49m 54.9318s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.109446s N, 29 49m 54.7685s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.145759s N, 29 49m 54.6052s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.182071s N, 29 49m 54.4419s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.218383s N, 29 49m 54.2785s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.254694s N, 29 49m 54.1152s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.291005s N, 29 49m 53.9519s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.327315s N, 29 49m 53.7886s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.363624s N, 29 49m 53.6253s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.399933s N, 29 49m 53.4619s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.436241s N, 29 49m 53.2986s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.472549s N, 29 49m 53.1353s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.508856s N, 29 49m 52.972s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.545162s N, 29 49m 52.8087s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.581468s N, 29 49m 52.6453s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.617773s N, 29 49m 52.482s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.654078s N, 29 49m 52.3187s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.690382s N, 29 49m 52.1554s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.726685s N, 29 49m 51.992s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.762988s N, 29 49m 51.8287s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.79929s N, 29 49m 51.6654s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.835591s N, 29 49m 51.5021s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.871892s N, 29 49m 51.3387s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.908192s N, 29 49m 51.1754s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.944491s N, 29 49m 51.0121s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.980789s N, 29 49m 50.8487s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.01709s N, 29 49m 50.6854s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.05338s N, 29 49m 50.5221s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.08968s N, 29 49m 50.3587s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.12598s N, 29 49m 50.1954s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.16227s N, 29 49m 50.0321s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.19857s N, 29 49m 49.8687s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.23486s N, 29 49m 49.7054s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.27115s N, 29 49m 49.5421s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.30744s N, 29 49m 49.3787s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.33648s N, 29 49m 49.2481s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.37277s N, 29 49m 49.0847s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.40906s N, 29 49m 48.9214s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.44535s N, 29 49m 48.7581s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.48163s N, 29 49m 48.5947s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.51792s N, 29 49m 48.4314s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.55421s N, 29 49m 48.268s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.59049s N, 29 49m 48.1047s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.62678s N, 29 49m 47.9413s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.66306s N, 29 49m 47.778s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.69935s N, 29 49m 47.6147s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.73563s N, 29 49m 47.4513s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.77191s N, 29 49m 47.288s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.80819s N, 29 49m 47.1246s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.84447s N, 29 49m 46.9613s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.88075s N, 29 49m 46.7979s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.91702s N, 29 49m 46.6346s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.9533s N, 29 49m 46.4712s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.98957s N, 29 49m 46.3079s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.02585s N, 29 49m 46.1445s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.06212s N, 29 49m 45.9812s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.09839s N, 29 49m 45.8178s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.13466s N, 29 49m 45.6544s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.17093s N, 29 49m 45.4911s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.2072s N, 29 49m 45.3277s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.24347s N, 29 49m 45.1644s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.27973s N, 29 49m 45.001s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.316s N, 29 49m 44.8377s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.35226s N, 29 49m 44.6743s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.38852s N, 29 49m 44.5109s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.42479s N, 29 49m 44.3476s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.46104s N, 29 49m 44.1842s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.4973s N, 29 49m 44.0208s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.53356s N, 29 49m 43.8575s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.56981s N, 29 49m 43.6941s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.60607s N, 29 49m 43.5307s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.64232s N, 29 49m 43.3673s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.67857s N, 29 49m 43.204s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.71482s N, 29 49m 43.0406s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.75107s N, 29 49m 42.8772s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.78731s N, 29 49m 42.7138s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.82356s N, 29 49m 42.5505s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.8598s N, 29 49m 42.3871s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.89604s N, 29 49m 42.2237s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.93228s N, 29 49m 42.0603s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.96851s N, 29 49m 41.8969s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.00475s N, 29 49m 41.7335s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.04098s N, 29 49m 41.5701s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.07721s N, 29 49m 41.4067s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.11343s N, 29 49m 41.2433s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.14966s N, 29 49m 41.0799s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.17863s N, 29 49m 40.9492s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.21485s N, 29 49m 40.7858s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.25107s N, 29 49m 40.6224s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.28728s N, 29 49m 40.459s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.3235s N, 29 49m 40.2956s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.3597s N, 29 49m 40.1322s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.39591s N, 29 49m 39.9688s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.4321s N, 29 49m 39.8053s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.4683s N, 29 49m 39.6419s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.50449s N, 29 49m 39.4785s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.54067s N, 29 49m 39.3151s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.57685s N, 29 49m 39.1516s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.61303s N, 29 49m 38.9882s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.64919s N, 29 49m 38.8247s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.68535s N, 29 49m 38.6613s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.7215s N, 29 49m 38.4978s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.75763s N, 29 49m 38.3343s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.79375s N, 29 49m 38.1708s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 160)
# [ИНФО][CONTROL] новое направление 169 (было 293)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.82986s N, 29 49m 38.0073s E
# [ИНФО][CONTROL] новое направление 168 (было 169)
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.86593s N, 29 49m 37.8438s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.90195s N, 29 49m 37.6802s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.63726s N, 29 49m 37.7787s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.37309s N, 29 49m 37.8825s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.10945s N, 29 49m 37.9915s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.84585s N, 29 49m 38.1009s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.58227s N, 29 49m 38.2106s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.3187s N, 29 49m 38.3203s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.05513s N, 29 49m 38.43s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.79157s N, 29 49m 38.5397s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.528s N, 29 49m 38.6494s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.26443s N, 29 49m 38.7592s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.00087s N, 29 49m 38.8689s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.737303s N, 29 49m 38.9787s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.47374s N, 29 49m 39.0884s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.210179s N, 29 49m 39.1982s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.9466s N, 29 49m 39.308s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6831s N, 29 49m 39.4178s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4195s N, 29 49m 39.5276s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1559s N, 29 49m 39.6375s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8924s N, 29 49m 39.7473s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6288s N, 29 49m 39.8572s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.3653s N, 29 49m 39.9671s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.1017s N, 29 49m 40.077s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.8382s N, 29 49m 40.187s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.5747s N, 29 49m 40.2969s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.3111s N, 29 49m 40.407s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.0476s N, 29 49m 40.5171s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 206 (было 168)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.7841s N, 29 49m 40.6272s E
# [ИНФО][CONTROL] новое направление 211 (было 206)
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.5206s N, 29 49m 40.7375s E
# [ИНФО][CONTROL] новое направление 216 (было 211)
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.3098s N, 29 49m 40.826s E
# [ИНФО][CONTROL] новое направление 219 (было 216)
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.0644s N, 29 49m 40.6566s E
# [ИНФО][CONTROL] новое направление 221 (было 219)
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.8329s N, 29 49m 40.3837s E
# [ИНФО][CONTROL] новое направление 223 (было 221)
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.6141s N, 29 49m 40.0718s E
# [ИНФО][CONTROL] новое направление 224 (было 223)
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.4069s N, 29 49m 39.7298s E
# [ИНФО][CONTROL] новое направление 227 (было 224)
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.2057s N, 29 49m 39.3736s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 201 (было 227)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.0101s N, 29 49m 39.0055s E
# [ИНФО][CONTROL] новое направление 199 (было 201)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8194s N, 29 49m 38.6272s E
# [ИНФО][CONTROL] новое направление 196 (было 199)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6362s N, 29 49m 38.2347s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3855s N, 29 49m 38.0392s E
# [ИНФО][CONTROL] новое направление 195 (было 196)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1314s N, 29 49m 37.8618s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8735s N, 29 49m 37.7076s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.615s N, 29 49m 37.5579s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.3559s N, 29 49m 37.4115s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.0967s N, 29 49m 37.2662s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.8375s N, 29 49m 37.1216s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.5781s N, 29 49m 36.9773s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.3188s N, 29 49m 36.8332s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 204 (было 195)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.0594s N, 29 49m 36.6891s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.8001s N, 29 49m 36.5451s E
# [ИНФО][CONTROL] новое направление 205 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.5407s N, 29 49m 36.4009s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.2961s N, 29 49m 36.1771s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.0518s N, 29 49m 35.9515s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.808s N, 29 49m 35.7242s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.5642s N, 29 49m 35.4967s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.3204s N, 29 49m 35.2692s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.0766s N, 29 49m 35.0417s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.8329s N, 29 49m 34.8142s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.5891s N, 29 49m 34.5867s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.3453s N, 29 49m 34.3592s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.1015s N, 29 49m 34.1317s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.8577s N, 29 49m 33.9041s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.614s N, 29 49m 33.6766s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.3702s N, 29 49m 33.449s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.1264s N, 29 49m 33.2214s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.8827s N, 29 49m 32.9939s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.6389s N, 29 49m 32.7663s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.3951s N, 29 49m 32.5387s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.1514s N, 29 49m 32.3111s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.9076s N, 29 49m 32.0835s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.6638s N, 29 49m 31.8559s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.4201s N, 29 49m 31.6282s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.1763s N, 29 49m 31.4006s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.9326s N, 29 49m 31.1729s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.6888s N, 29 49m 30.9453s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.4451s N, 29 49m 30.7176s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.2014s N, 29 49m 30.4899s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.9576s N, 29 49m 30.2621s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.7139s N, 29 49m 30.0344s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.4702s N, 29 49m 29.8067s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.2265s N, 29 49m 29.5789s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.0315s N, 29 49m 29.3966s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.7878s N, 29 49m 29.1688s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.5441s N, 29 49m 28.941s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.3004s N, 29 49m 28.7131s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.0567s N, 29 49m 28.4852s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.813s N, 29 49m 28.2573s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.5693s N, 29 49m 28.0293s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.3257s N, 29 49m 27.8013s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.082s N, 29 49m 27.5732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.8384s N, 29 49m 27.345s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.5948s N, 29 49m 27.1167s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.3512s N, 29 49m 26.8884s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.1077s N, 29 49m 26.6599s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 113 (было 205)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.8642s N, 29 49m 26.4313s E
# [ИНФО][CONTROL] новое направление 111 (было 113)
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6207s N, 29 49m 26.2023s E
# [ИНФО][CONTROL] новое направление 110 (было 111)
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3775s N, 29 49m 25.9723s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.272s N, 29 49m 26.4651s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1718s N, 29 49m 26.9623s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0769s N, 29 49m 27.4636s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9822s N, 29 49m 27.9651s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8877s N, 29 49m 28.4666s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7932s N, 29 49m 28.9682s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6987s N, 29 49m 29.4698s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6042s N, 29 49m 29.9714s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5097s N, 29 49m 30.473s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4152s N, 29 49m 30.9746s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3207s N, 29 49m 31.4762s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2262s N, 29 49m 31.9777s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1317s N, 29 49m 32.4793s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0372s N, 29 49m 32.9809s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9427s N, 29 49m 33.4825s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8483s N, 29 49m 33.9841s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7538s N, 29 49m 34.4857s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6593s N, 29 49m 34.9874s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5649s N, 29 49m 35.489s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4704s N, 29 49m 35.9906s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3759s N, 29 49m 36.4922s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2815s N, 29 49m 36.9938s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.187s N, 29 49m 37.4954s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0926s N, 29 49m 37.9971s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9982s N, 29 49m 38.4987s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9037s N, 29 49m 39.0003s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8093s N, 29 49m 39.502s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7149s N, 29 49m 40.0036s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6205s N, 29 49m 40.5052s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5261s N, 29 49m 41.0069s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4317s N, 29 49m 41.5086s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3373s N, 29 49m 42.0102s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2429s N, 29 49m 42.5119s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1485s N, 29 49m 43.0136s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0542s N, 29 49m 43.5152s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9598s N, 29 49m 44.0169s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8844s N, 29 49m 44.4183s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.79s N, 29 49m 44.92s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.6957s N, 29 49m 45.4217s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.6014s N, 29 49m 45.9234s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.5071s N, 29 49m 46.4252s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4129s N, 29 49m 46.9269s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3186s N, 29 49m 47.4287s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.2244s N, 29 49m 47.9305s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.1303s N, 29 49m 48.4323s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0361s N, 29 49m 48.9342s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 60)
# [ИНФО][CONTROL] новое направление 213 (было 110)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9421s N, 29 49m 49.4361s E
# [ИНФО][CONTROL] новое направление 223 (было 213)
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.8482s N, 29 49m 49.9381s E
# [ИНФО][CONTROL] новое направление 233 (было 223)
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.7545s N, 29 49m 50.4403s E
# [ИНФО][CONTROL] новое направление 234 (было 233)
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6792s N, 29 49m 50.343s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6144s N, 29 49m 50.2195s E
# [ИНФО][CONTROL] новое направление 235 (было 234)
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5605s N, 29 49m 50.0768s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5081s N, 29 49m 49.9318s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4566s N, 29 49m 49.7856s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4053s N, 29 49m 49.6391s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.354s N, 29 49m 49.4925s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3028s N, 29 49m 49.3459s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2516s N, 29 49m 49.1992s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2004s N, 29 49m 49.0526s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.1492s N, 29 49m 48.9059s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0981s N, 29 49m 48.7592s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0469s N, 29 49m 48.6125s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9957s N, 29 49m 48.4658s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9446s N, 29 49m 48.319s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 14:17:41.951875
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 235)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Разблокирован грузовой отсек
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.8935s N, 29 49m 48.1723s E
# [ОШИБКА][SAFETY] Заданное направление 0.0 отличается от верного.
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# #### *Опциональное задание повышенной сложности* Обеспечение ЦБ2
#
# **Перед началом работы над этой задачей рекомендуем сохранить все текущие изменения в git репозитории (git commit, git push).**
#
# Напомним цель безопасности №2 (ЦБ2): "При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут"
#
# Обеспечение ЦБ2 потребует
# - внедрения механизма **контроля аутентичности маршрутного задания** (mission), а значит
# - помимо изменения **блока безопасности** (SafetyBlock), модификации
#   - системы **планирования задания** (MissionPlanner)
#   - **коммуникационного шлюза** (CommunicationGateway)
#   - и, возможно, **системы управления** (ControlSystem).
#
# Для решения этой задачи допустимо менять код соответствующих модулей в папке src.
#
# Возможным решением является внедрение механизма цифровой подписи, верификацией которой будет заниматься блок безопасности. В этой ситуации если коммуникационный шлюз (блок "1. Связь" на рис. 5 в модуле 1) оказался скомпрометированным и изменил маршрутное задание, оно не должно пройти проверку подлинности в блоке безопасности.
#
# **Рекомендуем эту задачу делать в последнюю очередь**, *после успешного выполнения модуля 4*, поскольку успешное выполнение модуля 4 принесёт больше баллов, чем внедрение цифровой подписи и обеспечение ЦБ2.
# К сведению, реализованные в этой версии киберпрепятствия не предполагают компрометацию маршрутного задания.
#
# Конечно, если будут решены все основные задачи и к тому же обеспечен контроль аутентичности маршрутного задания, такая работа с высокой вероятностью окажется лучшей.

# %%
# если вы собираетесь выполнить это задание, напишите в этой ячейке код выполнения изменённых блоков. 
# cам код допускается редактировать в папке src
# в случае успешной реализации машинка должна успешно пройти по маршруту, а в случае искажения маршрутного задания в блоке коммуникационного шлюза должна остаться на месте, 
# при этом именно блок безопасности должен заблокировать движение

# %% [markdown]
# ### Задание 3.2. Монитор безопасности

# %% [markdown]
# В текущей реализации каждый блок сам решает куда и какие данные ему отправлять. Это приемлемо, когда каждый блок рассматривается как благонадёжный. Однако нельзя исключать ситуацию успешной компрометации какого-либо из блоков (одного или нескольких), в результате которой злоумышленник может получить полный контроль над частью системы.
#
# В такой ситуации необходимо выстроить внутреннюю "поверхность защиты", частью этой системы уже является блок "Ограничитель", однако необходимо сделать так, чтобы соответствующие запросы проходили только через него, а не в обход.
#
# Для решения этой задачи необходимо добавить новый блок "Монитор безопасности". Его задача - обеспечить контроль направления информационных потоков, допустить передачу данных только между теми блоками и в тех направлениях, которые задуманы архитектором системы. Тогда, например, попытка передать команду из системы управления напрямую в сервоприводы в обход ограничителя будет заблокирована.
#
# Возможно, возникнет вопрос, а что помешает злоумышленнику отправить команду в обход этого монитора безопасности. В рамках этой учебной инфраструктуры особо ничего, однако при разработке реальной системы можно использовать специализированные микроядерные операционные системы, такие как, например, KasperskyOS, которые обеспечат обязательное вовлечение монитора безопасности в контроль взаимодействия между блоками.
#
# Архитектура системы для решения задачи 3.2 должна выглядеть как на рис.8:
#
# ![Архитектура системы с монитором безопасности](images/ciac-arch-m32.png)
#
# Рис. 8. Архитектура бортовых систем с монитором безопасности

# %% [markdown]
# Базовый класс модуля безопасности находится в файле src/security_monitor.py, его менять не нужно.
#
# В следующей ячейке находится реализация класса SecurityMonitor

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO, SAFETY_BLOCK_QUEUE_NAME, NAVIGATION_QUEUE_NAME
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [

            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='release_cargo'
            ),
             SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_speed'
            ),
             SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='release_cargo'
            )

        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Обратите внимание на этот код:
# ```python
#     def _init_set_security_policies(self):
#         """ инициализация политик безопасности """
#         default_policies = [
#             SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
#         ]
#         self.set_security_policies(policies=default_policies)
# ```
#
# В нём инициализируется политика безопасности, разрешающая запрос set_mission от коммуникационного шлюза в систему управления.
#
# Код политики безопасности в строка 6-9:
# ```python
# SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
# ```
#
# Шаблон политики безопасности описан в файле src/security_policy_type.py:
# ```python
# @dataclass
# class SecurityPolicy:
#     """ политика безопасности """
#     source: str         # отправитель запроса
#     destination: str    # получатель
#     operation: str      # запрашиваемая операция
#
# ```
#
# По аналогии в методе _init_set_security_policies допишите другие политики безопасности, чтобы разрешить взаимодействия согласно диаграмме на рис.7. выше.

# %% [markdown]
# Теперь необходимо изменить взаимодействие между блоками так, чтобы оно всегда проходило через монитор безопасности. Для этого потребуется изменить соответствующие реализации внутренних блоков.

# %% [markdown]
# Ниже пример для блока навигации. Обратите внимание на выделенные строки и комментарии.
#
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         # событие для системы управления,
#         # поэтому в destination указываем CONTROL_SYSTEM_QUEUE_NAME
#         event = Event(source=self.event_source_name,
# >>>                      destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         # но событие отправляем сначала на проверку в монитор безопасности,
#         # поэтому используем очередь с именем SECURITY_MONITOR_QUEUE_NAME
# >>>        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#         # а в систему управления наше событие монитор безопасности отправит сам, если найдёт разрешающую эту операцию политику безопасности
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         event = Event(source=self.event_source_name,
#                       destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)

# %% [markdown]
# В файле tests/module/test_security_monitor.py можно увидеть тест логики работы монитора безопасности. Запустить его можно следующей командой:

# %%
# !pytest -svk security_monitor
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.12, pytest-8.3.4, pluggy-1.5.0 -- /bin/python3
# cachedir: .pytest_cache
# rootdir: /home/eldar/Документы/Uni/Systems/cyberimmune-autonomy--chvt-preview
# configfile: pytest.ini
# testpaths: tests
# collected 1 item
#
# tests/module/test_security_monitor.py::test_security_policies [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='control', operation='set_mission', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='cargo', operation='release_cargo', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# PASSED
#
# ============================== 1 passed in 0.01s ===============================

# %% [markdown]
# В одном кодовом блоке ниже (или нескольких - как будет удобнее)  сделайте следующее
#
# 1. Измените реализацию монитора безопасности в части правил проверки передаваемых сообщений в мониторе безопасности
# 2. Измените параметры отправки сообщений между элементами бортовых систем (блоками 1-7), чтобы они всегда отправлялись в очередь монитора безопасности (отправитель и получатель при этом не меняются)
# 3. После всех изменений убедитесь в том, что машинка по-прежнему успешно выполняет маршрутное задание и доставляет груз
# 4. Дополнительные баллы принесут автоматические тесты правил безопасности в файле tests/module/test_security_monitor.py - можно проверить, что все новые политики работают как ожидаются, а недопустимые взаимодействия (т.е. таких стрелок нет на рис. 8) блокируются

# %%
# добавьте изменения сюда

from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.event_types import Event

class CommunicationGateway(BaseCommunicationGateway):
    """Коммуникационный шлюз"""
    def _send_mission_to_consumers(self):
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        control_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(control_event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


class ControlSystem(BaseControlSystem):
    """Система управления"""
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        # Добавим создание очереди безопасности
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # Заменим destination на очередь безопасности
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                      )

        event_direction = Event(source=BaseControlSystem.event_source_name,
                          destination=safety_q_name,
                          operation="set_direction", parameters=direction
                          )

        # Положим события в очередь
        safety_q.put(event_speed)
        safety_q.put(event_direction)
    
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """

        # Добавим очередь безопасности для выполнения ЦБ
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=safety_q_name,
                      operation="lock_cargo",
                      parameters=None
                      )
        
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """

        # Добавим очередь безопасности для выполнения ЦБ
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=safety_q_name,
                      operation="release_cargo",
                      parameters=None
                      )
        
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

class NavigationSystem(BaseNavigationSystem):
    """Система навигации"""
    def _send_position_to_consumers(self):        
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        event = Event(source=BaseNavigationSystem.event_source_name,
                          destination=control_q_name,
                          operation="position_update", parameters=self._position
                          )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _emergency_stop(self):
        """Аварийная остановка"""
        # Устанавливаем скорость на 0
        self._speed = 0
        self._direction = 0
        
        # Записываем в лог сообщение об остановке и сообщаем координаты
        self._log_message(LOG_FAILURE, f'Произошла аварийная остановка. Текущие координаты: {self._position}.')
    
    def _calculate_direction(self):
        """Вычисляем направление движения к следующей точке маршрута"""
        if not self._route.next_point():
            # Предусмотрим нахождение в последней точке маршрута
            return self._direction
        cur_lat = radians(self._position.latitude)
        dest_lat = radians(self._route.next_point().latitude)
        long = radians(self._route.next_point().longitude - self._position.longitude)

        x = sin(long) * cos(dest_lat)
        y = cos(cur_lat) * sin(dest_lat) - sin(cur_lat) * cos(dest_lat) * cos(long)

        return (degrees(atan2(x, y)) + 360) % 360

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        
        # Если новое направление отличается от правильного по модулю более чем на 1 градус, не разрешаем изменение
        waypoint_direction = self._calculate_direction()
        if (abs(waypoint_direction - direction) >= 1):
            self._log_message(LOG_ERROR, f'Заданное направление {direction} отличается от верного.')
            self._direction = waypoint_direction
            self._send_direction_to_consumers()
            # self._emergency_stop()
            return

        self._direction = direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        
        # Находим ограничение по скорости
        speed_limit = self._route.calculate_speed()

        # Проверяем соответствие нового значения ограничениям
        if speed > speed_limit:
            # В случае некорректного значения не меняем скорость
            self._log_message(LOG_ERROR, f'Заданная скорость {speed} превышает ограничение {speed_limit}.')
        else:
            # В случае корректрного значения устанавливаем новую скорость
            self._speed = speed
        # Отправляем сообщение с новым значением скорости
        self._send_speed_to_consumers()


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)
    
    def _lock_cargo(self, _):
        # Передаем сообщения
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._log_message(LOG_DEBUG, "Передана команда на блокировку грузового отсека")

        cargo_q_name = CARGO_BAY_QUEUE_NAME

        event = Event(source=self.event_source_name,
                      destination=cargo_q_name,
                      operation="lock_cargo",
                      parameters=None
                      )
        
        cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)
        cargo_q.put(event)
    
    def _release_cargo(self, _):
        # Передаем сообщения
        self._log_message(LOG_DEBUG, "Передана команда на разблокировку грузового отсека")

        if self._route.route_finished:
            cargo_q_name = CARGO_BAY_QUEUE_NAME

            event = Event(source=self.event_source_name,
                        destination=cargo_q_name,
                        operation="release_cargo",
                        parameters=None
                        )
            
            cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)
            cargo_q.put(event)

            self._log_message(LOG_INFO, "Разблокирован грузовой отсек")
        else:
            self._log_message(LOG_DEBUG, "Маршрут не пройден, отказано в разблокировке грузового отсека.")


from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO, SAFETY_BLOCK_QUEUE_NAME, NAVIGATION_QUEUE_NAME
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [

            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='release_cargo'
            ),
             SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_speed'
            ),
             SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='release_cargo'
            )

        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized


# Создаем экземпляры измененных классов
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)

# создадим все остальные компоненты

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(200)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2279s N, 29 50m 3.73262s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2585s N, 29 50m 3.56468s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.289s N, 29 50m 3.39675s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3134s N, 29 50m 3.2624s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3439s N, 29 50m 3.09445s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3744s N, 29 50m 2.92649s E
# [ОШИБКА][SAFETY] Заданное направление 26.041930331195204 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4049s N, 29 50m 2.75851s E
# [ОШИБКА][SAFETY] Заданное направление 20.542150288742505 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4353s N, 29 50m 2.59051s E
# [ОШИБКА][SAFETY] Заданное направление 15.029886071472504 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3547s N, 29 50m 2.5121s E
# [ОШИБКА][SAFETY] Заданное направление 13.871659713110489 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2706s N, 29 50m 2.44944s E
# [ОШИБКА][SAFETY] Заданное направление 13.085322624831747 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1839s N, 29 50m 2.40313s E
# [ОШИБКА][SAFETY] Заданное направление 12.826697492944845 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0968s N, 29 50m 2.36032s E
# [ОШИБКА][SAFETY] Заданное направление 12.66754344294236 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0094s N, 29 50m 2.31988s E
# [ОШИБКА][SAFETY] Заданное направление 12.594453593030266 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9218s N, 29 50m 2.28024s E
# [ОШИБКА][SAFETY] Заданное направление 12.546694392769325 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8343s N, 29 50m 2.24108s E
# [ОШИБКА][SAFETY] Заданное направление 12.51745291591925 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7467s N, 29 50m 2.20214s E
# [ОШИБКА][SAFETY] Заданное направление 12.494195519488471 отличается от верного.
# [ИНФО][SAFETY] сегмент пройден
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.659s N, 29 50m 2.16334s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5714s N, 29 50m 2.12464s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.4838s N, 29 50m 2.086s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.519s N, 29 50m 1.92175s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5548s N, 29 50m 1.75797s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5911s N, 29 50m 1.59467s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6274s N, 29 50m 1.43137s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6638s N, 29 50m 1.26807s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7001s N, 29 50m 1.10477s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7364s N, 29 50m 0.941474s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7728s N, 29 50m 0.778175s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8091s N, 29 50m 0.614877s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8454s N, 29 50m 0.451578s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8818s N, 29 50m 0.288278s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9181s N, 29 50m 0.124978s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9544s N, 29 49m 59.9617s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9908s N, 29 49m 59.7984s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0271s N, 29 49m 59.6351s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0634s N, 29 49m 59.4718s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0997s N, 29 49m 59.3085s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1361s N, 29 49m 59.1452s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1724s N, 29 49m 58.9819s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2087s N, 29 49m 58.8186s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.245s N, 29 49m 58.6553s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2814s N, 29 49m 58.492s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3177s N, 29 49m 58.3286s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.354s N, 29 49m 58.1653s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3903s N, 29 49m 58.002s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4267s N, 29 49m 57.8387s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.463s N, 29 49m 57.6754s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4993s N, 29 49m 57.5121s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.5356s N, 29 49m 57.3488s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.5719s N, 29 49m 57.1855s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6083s N, 29 49m 57.0222s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6446s N, 29 49m 56.8589s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6809s N, 29 49m 56.6956s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.71s N, 29 49m 56.5649s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.7463s N, 29 49m 56.4016s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.7826s N, 29 49m 56.2383s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.8189s N, 29 49m 56.075s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.8552s N, 29 49m 55.9117s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.8916s N, 29 49m 55.7484s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.9279s N, 29 49m 55.5851s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.9642s N, 29 49m 55.4217s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.000500723s N, 29 49m 55.2584s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.0368153s N, 29 49m 55.0951s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.0731293s N, 29 49m 54.9318s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.109443s N, 29 49m 54.7685s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.145756s N, 29 49m 54.6052s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.182068s N, 29 49m 54.4419s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.21838s N, 29 49m 54.2785s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.254691s N, 29 49m 54.1152s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.291002s N, 29 49m 53.9519s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.327312s N, 29 49m 53.7886s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.363621s N, 29 49m 53.6253s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.39993s N, 29 49m 53.4619s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.436238s N, 29 49m 53.2986s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.472546s N, 29 49m 53.1353s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.508853s N, 29 49m 52.972s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.54516s N, 29 49m 52.8087s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.581465s N, 29 49m 52.6453s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.617771s N, 29 49m 52.482s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.654075s N, 29 49m 52.3187s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.690379s N, 29 49m 52.1554s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.726683s N, 29 49m 51.992s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.762985s N, 29 49m 51.8287s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.799287s N, 29 49m 51.6654s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.835588s N, 29 49m 51.5021s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.871889s N, 29 49m 51.3387s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.908189s N, 29 49m 51.1754s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.944488s N, 29 49m 51.0121s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.980787s N, 29 49m 50.8487s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.01708s N, 29 49m 50.6854s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.05338s N, 29 49m 50.5221s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.08968s N, 29 49m 50.3587s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.12597s N, 29 49m 50.1954s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.16227s N, 29 49m 50.0321s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.19856s N, 29 49m 49.8687s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.23486s N, 29 49m 49.7054s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.27115s N, 29 49m 49.5421s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.30744s N, 29 49m 49.3787s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.34373s N, 29 49m 49.2154s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.38002s N, 29 49m 49.0521s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.41631s N, 29 49m 48.8887s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.44534s N, 29 49m 48.7581s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.48163s N, 29 49m 48.5947s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.51792s N, 29 49m 48.4314s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.5542s N, 29 49m 48.268s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.59049s N, 29 49m 48.1047s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.62678s N, 29 49m 47.9413s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.66306s N, 29 49m 47.778s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.69935s N, 29 49m 47.6147s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.73563s N, 29 49m 47.4513s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.77191s N, 29 49m 47.288s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.80819s N, 29 49m 47.1246s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.84447s N, 29 49m 46.9613s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.88075s N, 29 49m 46.7979s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.91703s N, 29 49m 46.6346s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.9533s N, 29 49m 46.4712s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.98958s N, 29 49m 46.3079s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.02586s N, 29 49m 46.1445s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.06213s N, 29 49m 45.9812s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.0984s N, 29 49m 45.8178s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.13467s N, 29 49m 45.6545s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.17094s N, 29 49m 45.4911s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.20721s N, 29 49m 45.3277s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.24348s N, 29 49m 45.1644s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.27974s N, 29 49m 45.001s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.31601s N, 29 49m 44.8377s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.35227s N, 29 49m 44.6743s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.38853s N, 29 49m 44.5109s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.42479s N, 29 49m 44.3476s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.46105s N, 29 49m 44.1842s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.49731s N, 29 49m 44.0208s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.53357s N, 29 49m 43.8575s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.56982s N, 29 49m 43.6941s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.60607s N, 29 49m 43.5307s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.64233s N, 29 49m 43.3673s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.67858s N, 29 49m 43.204s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.71483s N, 29 49m 43.0406s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.75107s N, 29 49m 42.8772s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.78732s N, 29 49m 42.7138s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.82356s N, 29 49m 42.5505s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.8598s N, 29 49m 42.3871s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.89604s N, 29 49m 42.2237s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.93228s N, 29 49m 42.0603s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.96852s N, 29 49m 41.8969s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.00475s N, 29 49m 41.7335s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.04098s N, 29 49m 41.5701s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.07721s N, 29 49m 41.4067s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.11344s N, 29 49m 41.2433s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.14966s N, 29 49m 41.08s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.18588s N, 29 49m 40.9166s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.21486s N, 29 49m 40.7858s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.25107s N, 29 49m 40.6224s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.28729s N, 29 49m 40.459s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.3235s N, 29 49m 40.2956s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.3597s N, 29 49m 40.1322s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.39591s N, 29 49m 39.9688s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.43211s N, 29 49m 39.8054s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.4683s N, 29 49m 39.6419s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.50449s N, 29 49m 39.4785s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.54068s N, 29 49m 39.3151s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.57685s N, 29 49m 39.1516s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.61303s N, 29 49m 38.9882s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.64919s N, 29 49m 38.8247s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.68535s N, 29 49m 38.6613s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.7215s N, 29 49m 38.4978s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.75763s N, 29 49m 38.3343s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.79375s N, 29 49m 38.1708s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.82986s N, 29 49m 38.0073s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.86593s N, 29 49m 37.8438s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.90195s N, 29 49m 37.6802s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.63726s N, 29 49m 37.7787s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.37309s N, 29 49m 37.8825s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.10945s N, 29 49m 37.9915s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.84585s N, 29 49m 38.101s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.58227s N, 29 49m 38.2106s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.3187s N, 29 49m 38.3203s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.05513s N, 29 49m 38.43s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.79156s N, 29 49m 38.5397s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.528s N, 29 49m 38.6494s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.26443s N, 29 49m 38.7592s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.00087s N, 29 49m 38.8689s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.737302s N, 29 49m 38.9787s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.47374s N, 29 49m 39.0884s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.210178s N, 29 49m 39.1982s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.9466s N, 29 49m 39.308s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6831s N, 29 49m 39.4178s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4195s N, 29 49m 39.5276s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1559s N, 29 49m 39.6375s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8924s N, 29 49m 39.7473s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6288s N, 29 49m 39.8572s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.3653s N, 29 49m 39.9671s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.1017s N, 29 49m 40.077s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.8382s N, 29 49m 40.187s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.5747s N, 29 49m 40.2969s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.3111s N, 29 49m 40.407s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.0476s N, 29 49m 40.5171s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.7841s N, 29 49m 40.6272s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.5206s N, 29 49m 40.7375s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.2571s N, 29 49m 40.8481s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.0162s N, 29 49m 40.6088s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.787s N, 29 49m 40.3275s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.5748s N, 29 49m 39.9977s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.4102s N, 29 49m 39.7213s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.2093s N, 29 49m 39.3646s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.0129s N, 29 49m 38.9982s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.82s N, 29 49m 38.6244s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6327s N, 29 49m 38.2395s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3819s N, 29 49m 38.0447s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1278s N, 29 49m 37.8675s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.87s N, 29 49m 37.7127s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6115s N, 29 49m 37.5622s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.3526s N, 29 49m 37.415s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.0936s N, 29 49m 37.2688s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.8344s N, 29 49m 37.1233s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.5752s N, 29 49m 36.978s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.316s N, 29 49m 36.8329s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.0568s N, 29 49m 36.6879s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.7976s N, 29 49m 36.5429s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.5384s N, 29 49m 36.3977s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.2937s N, 29 49m 36.1739s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.0495s N, 29 49m 35.9483s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.8057s N, 29 49m 35.721s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.5619s N, 29 49m 35.4936s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.3181s N, 29 49m 35.2661s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.0743s N, 29 49m 35.0386s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.8305s N, 29 49m 34.8111s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.5867s N, 29 49m 34.5836s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.3429s N, 29 49m 34.3561s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.0991s N, 29 49m 34.1286s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.8554s N, 29 49m 33.9011s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.6116s N, 29 49m 33.6736s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.3678s N, 29 49m 33.446s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.124s N, 29 49m 33.2185s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.8803s N, 29 49m 32.9909s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.6365s N, 29 49m 32.7634s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.3927s N, 29 49m 32.5358s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.1489s N, 29 49m 32.3082s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.9052s N, 29 49m 32.0806s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.6614s N, 29 49m 31.853s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.4177s N, 29 49m 31.6254s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.1739s N, 29 49m 31.3978s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.9789s N, 29 49m 31.2157s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.7352s N, 29 49m 30.988s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.4914s N, 29 49m 30.7603s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.2477s N, 29 49m 30.5327s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.0039s N, 29 49m 30.305s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.7602s N, 29 49m 30.0773s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.5165s N, 29 49m 29.8495s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.2727s N, 29 49m 29.6218s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.029s N, 29 49m 29.394s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.7853s N, 29 49m 29.1662s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.5416s N, 29 49m 28.9383s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.2979s N, 29 49m 28.7105s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.0542s N, 29 49m 28.4825s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.8105s N, 29 49m 28.2546s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.5669s N, 29 49m 28.0266s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.3232s N, 29 49m 27.7986s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.0796s N, 29 49m 27.5705s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.8359s N, 29 49m 27.3424s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.5923s N, 29 49m 27.1142s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.3487s N, 29 49m 26.8859s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.1051s N, 29 49m 26.6575s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.8616s N, 29 49m 26.4289s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6182s N, 29 49m 26.1999s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.375s N, 29 49m 25.97s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2695s N, 29 49m 26.4629s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1693s N, 29 49m 26.9601s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0745s N, 29 49m 27.4614s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9988s N, 29 49m 27.8627s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9043s N, 29 49m 28.3642s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8099s N, 29 49m 28.8659s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7154s N, 29 49m 29.3675s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.621s N, 29 49m 29.8691s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5265s N, 29 49m 30.3707s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4321s N, 29 49m 30.8724s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3376s N, 29 49m 31.374s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2432s N, 29 49m 31.8756s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1488s N, 29 49m 32.3773s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0543s N, 29 49m 32.8789s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9599s N, 29 49m 33.3806s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8655s N, 29 49m 33.8822s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7711s N, 29 49m 34.3838s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6767s N, 29 49m 34.8855s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5822s N, 29 49m 35.3871s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4878s N, 29 49m 35.8888s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3934s N, 29 49m 36.3905s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.299s N, 29 49m 36.8921s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2046s N, 29 49m 37.3938s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1103s N, 29 49m 37.8954s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0159s N, 29 49m 38.3971s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9215s N, 29 49m 38.8988s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8271s N, 29 49m 39.4005s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7328s N, 29 49m 39.9022s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6384s N, 29 49m 40.4038s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5441s N, 29 49m 40.9055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4497s N, 29 49m 41.4072s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3554s N, 29 49m 41.9089s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2611s N, 29 49m 42.4106s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1667s N, 29 49m 42.9124s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0724s N, 29 49m 43.4141s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9781s N, 29 49m 43.9158s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9027s N, 29 49m 44.3172s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8084s N, 29 49m 44.8189s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.7142s N, 29 49m 45.3207s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.6199s N, 29 49m 45.8225s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.5257s N, 29 49m 46.3242s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4315s N, 29 49m 46.826s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3373s N, 29 49m 47.3278s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.2432s N, 29 49m 47.8297s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.149s N, 29 49m 48.3315s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.055s N, 29 49m 48.8334s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9609s N, 29 49m 49.3354s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.867s N, 29 49m 49.8374s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.7733s N, 29 49m 50.3395s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6962s N, 29 49m 50.2484s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6292s N, 29 49m 50.1295s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5731s N, 29 49m 49.9901s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5186s N, 29 49m 49.8483s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.465s N, 29 49m 49.705s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4116s N, 29 49m 49.5615s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3583s N, 29 49m 49.4179s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.305s N, 29 49m 49.2742s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2518s N, 29 49m 49.1305s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.1985s N, 29 49m 48.9867s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.1453s N, 29 49m 48.843s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.092s N, 29 49m 48.6992s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0388s N, 29 49m 48.5555s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9856s N, 29 49m 48.4117s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9324s N, 29 49m 48.2678s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Разблокирован грузовой отсек
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.8793s N, 29 49m 48.124s E
# [ОШИБКА][SAFETY] Заданное направление 0.0 отличается от верного.
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# На этом модуль 3 завершён!
#
# Если у вас всё получилось, то вы создали защищённую автономную машинку - ещё уже не так-то просто использовать для нанесения критического ущерба людям и имуществу, потому что самые критические режимы проверяются вашим Ограничителем, а если вы ещё и внедрили Монитор Безопасности, то теперь злоумышленнику гораздо сложнее атаковать внутренние блоки, даже если он смог проникнуть в какую-то бортовую систему или внедрить вредоносный код.
#
# Осталось проверить эффективность получившейся защиты на полной трассе - в этом и заключается модуль 4 задания, для перехода к которому нужно открыть блокнот с именем cyberimmunity--autonomous-car-m4. Успеха!
