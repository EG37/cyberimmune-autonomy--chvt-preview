# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 3
#
# ## О документе
#
# Версия 1.03
#
# Модуль 3 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 3. Внедрение блоков функциональной и информационной безопасности
# #### Общая идея
#
# Ключевая идея кибериммунной автономности заключается в том, чтобы уже на этапе проектирования внедрить защиту от кибератак как снаружи, так и изнутри - т.е. через уязвимые бортовые информационные системы.
# Мы исходим из того, что абсолютно защищённых систем не бывает, чем больше и сложнее код, тем проще одним ("плохим") в нём спрятать уязвимости, а другим ("хорошим", но уставшим) эти уязвимости не найти.
#
# Поэтому необходимо сделать так, чтобы наиболее критичный код был отделён от некритичного и протестирован особенно тщательно - таким образом можно снизить вероятность успешной атаки и затруднить задачу атакующим.

# %% [markdown]
# #### Цели и предположения безопасности
#
# ##### Цели безопасности
# Устойчивость кибериммунных систем к атакам выражается в том, что поставленные заказчиком **цели безопасности** (ЦБ) не нарушаются даже в условиях кибератак (снаружи и изнутри).
#
# Для наших автономных машинок заказчиком поставлены следующие ЦБ:
#
# 1. При любых обстоятельствах АНТС осуществляет перемещения в пределах заданных ограничений
#
# 2. При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут
#
# 3. При любых обстоятельствах АНТС оставляет груз только в авторизованном пункте назначения
#
# Ниже используется цифро-буквенное обозначение целей безопасности - например, ЦБ1 - первая цель безопасности из списка выше.
#
# ##### Предположения безопасности
# При этом заказчик согласовал с разработчиками следующие **предположения безопасности** (ПБ) - утверждения о смежных системах, которые снимают с разработчиков часть задач для обеспечения целей безопасности:
#
# 1. При любых обстоятельствах только авторизованный персонал имеет физический доступ к критическим узлам АНТС
#
# 2. При любых обстоятельствах только аутентичные и авторизованные операторы имеют доступ к системе планирования заданий
#
# 3. Аутентичные и авторизованные операторы обладают необходимой квалификацией и являются благонадёжными (т.е. не пытаются намеренно причинить ущерб системе или третьим лицам, используя доступ к АНТС)
#
# Ниже используется цифро-буквенное обозначение предположений безопасности - например, ПБ1 - первое предположение безопасности из списка выше.

# %% [markdown]
# ### Киберпрепятствия
#
# Прежде чем мы начнём внедрять механизмы безопасности, посмотрим, что произойдёт с нашей машинкой, если бортовые системы начнут вести себя не так, как мы ожидаем.
#
# Для этого активируем специальный режим работы системы управления и снова запустим машинку по тому же маршруту, который был в конце модуля 2.
#
# После инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# Но вначале нужно из модуля 2 скопировать сюда ваши текущие наработки, а именно ваши реализации классов коммуникационного шлюза (CommunicationGateway), систему навигации (NavigationSystem), управления (ControlSystem), также будем использовать маршрут, который вы создали.

# %%
from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.event_types import Event

class CommunicationGateway(BaseCommunicationGateway):
    """Коммуникационный шлюз"""
    def _send_mission_to_consumers(self):
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME

        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)


class ControlSystem(BaseControlSystem):
    """Система управления"""
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=servos_q_name,
                      operation="set_speed", parameters=speed
                      )

        event_direction = Event(source=BaseControlSystem.event_source_name,
                          destination=servos_q_name,
                          operation="set_direction", parameters=direction
                          )

        servos_q.put(event_speed)
        servos_q.put(event_direction)
    
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=CARGO_BAY_QUEUE_NAME,
                      operation="lock_cargo",
                      parameters=None
                      )
        cargo_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=CARGO_BAY_QUEUE_NAME,
                      operation="release_cargo",
                      parameters=None
                      )
        cargo_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """Система навигации"""
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseNavigationSystem.event_source_name,
                          destination=control_q_name,
                          operation="position_update", parameters=self._position
                          )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m3"

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "svetofor.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(2, 60),
    GeoSpecificSpeedLimit(8, 20),
]

home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

# по аналогии собираем все блоки в одном кузове
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# ограничение поездки по времени
# параметр sleep - время в секундах,
# настройте этот параметр так, чтобы ваша машинка завершила маршрут
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(135)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
del system_components
# Out:
# [Point(59.88311038619264, 29.834416819899282, 0.0), Point(59.88316739379213, 29.83410271042786, 0.0), Point(59.88292618713636, 29.833918984178702, 0.0), Point(59.884406447511914, 29.82718191038223, 0.0), Point(59.882409426144, 29.827965041591245, 0.0), Point(59.88192495544521, 29.827439378202076, 0.0), Point(59.88111210540939, 29.826849347867295, 0.0), Point(59.878027400845845, 29.82401720196725, 0.0), Point(59.87664497445017, 29.830429915603762, 0.0), Point(59.87634313737615, 29.830001068799085, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 14:34:48.963400
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 289 (было 0)
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 26 (было 289)
# [ИНФО][CONTROL] новое направление 20 (было 26)
# [ИНФО][CONTROL] новое направление 15 (было 20)
# [ИНФО][CONTROL] новое направление 16 (было 15)

# %% [markdown]
# Итак, в отличие от, надеемся, успешного завершения маршрута в модуле 2, сейчас ваша машинка ведёт себя совсем иначе. Например, она внезапно едет в совершенно другую сторону (это особенно хорошо видно при использовании СУПА).
# И это ещё не всё, что может пойти не так..
#
# В этой реализации не очень много кода, теоретически, вы можете его весь изучить и устранить "незадокументированные возможности", однако в реальных системах кода гораздо больше. Например, кодовая база проекта с открытым исходным кодом ArduPilot, реализующего в том числе логику автопилота, составляет примерно миллион строк.
#
# Сколько времени вам понадобится, чтобы изучить и протестировать миллион строк кода? А ведь придётся проводить анализ и каждого обновления.. При этом неприятности могут быть хорошо спрятанными и на первый взгляд безобидными, вряд ли злоумышленники облегчат задачу и назовут свои изменения, например, "hacking_the_system" или "allowing_secret_remote_access". Вредоносный код может выглядеть совершенно безобидно или маскироваться под программный дефект.
#
# Поэтому тщательный анализ потребует большого количества ресурсов (человеческих, вычислительных, временныз), что стоит дорого.
#
# Логичным выходом является выделение критичных для целей безопасности проверок в отдельный блок, который протестировать должно быть гораздо проще.

# %% [markdown]
# #### Задания
#
# В этом модуле задание будет состоять из двух частей разной сложности:
#
# **3.1. добавить новый блок - "Ограничитель"** - этот модуль должен будет обеспечить соблюдение ограничений, указанных в маршрутном задании - это необходимо для обеспечения ЦБ1
#
# **З.2. *(задание повышенной сложности)* добавить монитор безопасности (МБ)** - он должен контролировать все взаимодействия *бортовых систем* (т.е. не включая планировщик и симулятор) и не давать блокам взаимодействовать друг с другом непредусмотренным образом - например, блок №5 может принимать команды только от №3, попытка передать команду в №5 от №2 должна блокироваться нашим монитором безопасности - потенциально это необходимо для обеспечения всех ЦБ

# %% [markdown]
# Для выполнения первой части задачи 3.1. необходимо для начала изменить архитектуру АНТС как показано на рис. 5
#
# ![Архитектура системы с ограничителем](images/ciac-arch-m31.png)
#
# Рис. 5. Архитектура АНТС с ограничителем (для ЦБ1)

# %% [markdown]
# Код базового класса Ограничителя находится в файле src/safety_block.py
#
# По аналогии с заданием в модуле 1, необходимо создать на основе этого класса свой собственный под названием SafetyBlock, в котором реализовать передачу команд в приводы движения, только перед эти необходимо ещё и проконтролировать их безопасность.
#
# Также необходимо реализовать передачу маршрутного задания из CommunicationGateway в SafetyBlock и координат из модуля Navigation в соответствии со стрелками на рис.5 выше.
#
# Если всё сделано правильно, то Ограничителю будет известно следующее
#
# - _mission - текущее маршрутное задание
# - _position - текущие координаты
#
# После проверки нужно установить значение внутренних переменных
# - _speed - текущая (допустимая) скорость
# - _direction - текущее (допустимое) направление
#
# Желательно завершить следование по маршруту. В критической ситуации, если продолжение маршрута невозможно, следует установить значение скорости и направления в 0, после чего передать эти команды в блок приводов (Servos)

# %% [markdown]
# Базовый сценарий для новой архитектуры можно представить следующим образом (см. рис. 6)
#
# ![Базовый сценарий с блоком безопасности](images/basic-scenario-with-safety-block1.png)
#
# Рис. 6. Базовый сценарий с блоком безопасности

# %% [markdown]
# Заготовка кода SafetyBlock
#
# ```python
# class SafetyBlock(BaseSafetyBlock):
#     """ класс ограничений безопасности """
#
#     def _set_new_direction(self, direction: float):
#         """ установка нового направления перемещения """
#         self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
#         self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
#         self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
#         # TODO реализовать контроль безопасности изменения направления
#         self._direction = direction
#         self._send_direction_to_consumers()
#
#     def _set_new_speed(self, speed: float):
#         """ установка новой скорости """
#         # TODO реализовать контроль безопасности изменения скорости
#         self._speed = speed
#         self._send_speed_to_consumers()
#
#
#     def _send_speed_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем скорость получателям")
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_speed",
#                             parameters=self._speed
#                             )
#         servos_q.put(event_speed)
#
#     def _send_direction_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем направление получателям")
#
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_direction",
#                             parameters=self._direction
#                             )
#         servos_q.put(event_speed)
# ```

# %%
from src.safety_block import BaseSafetyBlock
from src.config import LOG_FAILURE, LOG_DEBUG
from math import radians, sin, cos, degrees, atan2


# 1. скопируйте сюда код заготовки из предыдущей ячейки и напишите свою реализацию класса SafetyBlock
class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _emergency_stop(self):
        """Аварийная остановка"""
        # Устанавливаем скорость на 0
        self._speed = 0
        self._direction = 0
        
        # Записываем в лог сообщение об остановке и сообщаем координаты
        self._log_message(LOG_FAILURE, f'Произошла аварийная остановка. Текущие координаты: {self._position}.')
    
    def _calculate_direction(self):
        """Вычисляем направление движения к следующей точке маршрута"""
        cur_lat = radians(self._position.latitude)
        dest_lat = radians(self._route.next_point().latitude)
        long = radians(self._route.next_point().longitude - self._position.longitude)

        x = sin(long) * cos(dest_lat)
        y = cos(cur_lat) * sin(dest_lat) - sin(cur_lat) * cos(dest_lat) * cos(long)

        return (degrees(atan2(x, y)) + 360) % 360

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        
        # Если новое направление отличается от правильного по модулю более чем на 1 градус, не разрешаем изменение
        waypoint_direction = self._calculate_direction()
        if (abs(waypoint_direction - direction) >= 1):
            self._log_message(LOG_ERROR, f'Заданное направление {direction} отличается от верного.')
            self._emergency_stop()
            return

        self._direction = direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        
        # Находим ограничение по скорости
        speed_limit = self._route.calculate_speed()

        # Проверяем соответствие нового значения ограничениям
        if speed > speed_limit:
            # В случае некорректного значения не меняем скорость
            self._log_message(LOG_ERROR, f'Заданная скорость {speed} превышает ограничение {speed_limit}.')
        else:
            # В случае корректрного значения устанавливаем новую скорость
            self._speed = speed
        # Отправляем сообщение с новым значением скорости
        self._send_speed_to_consumers()


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)

# %%
# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# 3. создайте экземпляры изменённых классов и отправьте машинку по ранее предложенному маршруту


from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.event_types import Event

class CommunicationGateway(BaseCommunicationGateway):
    """Коммуникационный шлюз"""
    def _send_mission_to_consumers(self):
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        control_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(control_event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


class ControlSystem(BaseControlSystem):
    """Система управления"""
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        # Добавим создание очереди безопасности
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # Заменим destination на очередь безопасности
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                      )

        event_direction = Event(source=BaseControlSystem.event_source_name,
                          destination=safety_q_name,
                          operation="set_direction", parameters=direction
                          )

        # Положим события в очередь
        safety_q.put(event_speed)
        safety_q.put(event_direction)

class NavigationSystem(BaseNavigationSystem):
    """Система навигации"""
    def _send_position_to_consumers(self):        
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        event = Event(source=BaseNavigationSystem.event_source_name,
                          destination=control_q_name,
                          operation="position_update", parameters=self._position
                          )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


# Создаем экземпляры измененных классов
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
# Out:
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь communication

# %%
# создадим все остальные компоненты

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)
# Out:
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель

# %%
# соберём все компоненты для запуска

# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(130)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2279s N, 29 50m 3.73262s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2585s N, 29 50m 3.56468s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2829s N, 29 50m 3.43034s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3134s N, 29 50m 3.2624s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3439s N, 29 50m 3.09445s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3744s N, 29 50m 2.92649s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4049s N, 29 50m 2.75852s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4353s N, 29 50m 2.59051s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3547s N, 29 50m 2.51211s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2706s N, 29 50m 2.44944s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1839s N, 29 50m 2.40313s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0968s N, 29 50m 2.36032s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0094s N, 29 50m 2.31989s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9218s N, 29 50m 2.28024s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8343s N, 29 50m 2.24108s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7467s N, 29 50m 2.20214s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6591s N, 29 50m 2.16335s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5714s N, 29 50m 2.12464s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.4838s N, 29 50m 2.08601s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5895s N, 29 50m 1.59325s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6968s N, 29 50m 1.10191s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8058s N, 29 50m 0.61199s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9148s N, 29 50m 0.122127s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0239s N, 29 49m 59.6323s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1329s N, 29 49m 59.1425s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.242s N, 29 49m 58.6526s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.351s N, 29 49m 58.1628s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4601s N, 29 49m 57.6729s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.5691s N, 29 49m 57.1831s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6782s N, 29 49m 56.6932s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.7872s N, 29 49m 56.2033s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.8962s N, 29 49m 55.7135s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.00526399s N, 29 49m 55.2236s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.114285s N, 29 49m 54.7337s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.2233s N, 29 49m 54.2439s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.332311s N, 29 49m 53.754s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.441316s N, 29 49m 53.2641s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.550315s N, 29 49m 52.7742s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.659309s N, 29 49m 52.2843s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.768298s N, 29 49m 51.7944s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.87728s N, 29 49m 51.3045s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.964461s N, 29 49m 50.9125s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.07343s N, 29 49m 50.4226s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.1824s N, 29 49m 49.9327s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.29136s N, 29 49m 49.4427s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.40031s N, 29 49m 48.9528s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.50925s N, 29 49m 48.4628s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.61819s N, 29 49m 47.9729s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.72711s N, 29 49m 47.4829s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.83603s N, 29 49m 46.9929s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.94494s N, 29 49m 46.503s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.05384s N, 29 49m 46.013s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.16273s N, 29 49m 45.523s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.27162s N, 29 49m 45.033s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.38049s N, 29 49m 44.5429s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.48934s N, 29 49m 44.0529s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.59819s N, 29 49m 43.5629s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.70702s N, 29 49m 43.0728s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.81584s N, 29 49m 42.5828s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.92464s N, 29 49m 42.0927s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.03342s N, 29 49m 41.6026s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.14219s N, 29 49m 41.1125s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.25093s N, 29 49m 40.6223s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.35964s N, 29 49m 40.1322s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.46832s N, 29 49m 39.642s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.57697s N, 29 49m 39.1518s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.68556s N, 29 49m 38.6615s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.79409s N, 29 49m 38.1712s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.90252s N, 29 49m 37.6808s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 4.01075s N, 29 49m 37.1902s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 4.11827s N, 29 49m 36.699s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.85463s N, 29 49m 36.808s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.59268s N, 29 49m 36.9322s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.33258s N, 29 49m 37.0708s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.07263s N, 29 49m 37.2106s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.81275s N, 29 49m 37.3509s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.55289s N, 29 49m 37.4913s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.29303s N, 29 49m 37.6317s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.03317s N, 29 49m 37.7721s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.82528s N, 29 49m 37.8845s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.56543s N, 29 49m 38.025s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.30557s N, 29 49m 38.1654s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.04572s N, 29 49m 38.3059s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.785871s N, 29 49m 38.4464s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.526022s N, 29 49m 38.5869s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.266176s N, 29 49m 38.7275s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.00633105s N, 29 49m 38.868s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.7465s N, 29 49m 39.0086s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4866s N, 29 49m 39.1491s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2268s N, 29 49m 39.2897s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.967s N, 29 49m 39.4304s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7071s N, 29 49m 39.571s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.4473s N, 29 49m 39.7117s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.1875s N, 29 49m 39.8524s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.9277s N, 29 49m 39.9931s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.6679s N, 29 49m 40.1339s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.4081s N, 29 49m 40.2747s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.1483s N, 29 49m 40.4156s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.8885s N, 29 49m 40.5566s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.6287s N, 29 49m 40.6977s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.369s N, 29 49m 40.839s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.1093s N, 29 49m 40.9811s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.875s N, 29 49m 40.7172s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.6562s N, 29 49m 40.405s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.4596s N, 29 49m 40.039s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.2718s N, 29 49m 39.655s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.0925s N, 29 49m 39.2552s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.9194s N, 29 49m 38.8449s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7537s N, 29 49m 38.4226s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6016s N, 29 49m 37.9806s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3496s N, 29 49m 37.7918s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0932s N, 29 49m 37.6276s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8324s N, 29 49m 37.495s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5707s N, 29 49m 37.3687s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.3084s N, 29 49m 37.2472s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.046s N, 29 49m 37.1272s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.7834s N, 29 49m 37.0083s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.5208s N, 29 49m 36.8898s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.2582s N, 29 49m 36.7717s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.048s N, 29 49m 36.6774s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.7853s N, 29 49m 36.5596s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.5226s N, 29 49m 36.4421s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.2744s N, 29 49m 36.2395s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.0301s N, 29 49m 36.0139s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.7865s N, 29 49m 35.786s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.543s N, 29 49m 35.5571s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.2996s N, 29 49m 35.3279s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.0562s N, 29 49m 35.0988s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.8128s N, 29 49m 34.8696s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.5694s N, 29 49m 34.6405s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.326s N, 29 49m 34.4113s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.0826s N, 29 49m 34.1821s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.8393s N, 29 49m 33.9529s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.5959s N, 29 49m 33.7237s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.3525s N, 29 49m 33.4945s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.1091s N, 29 49m 33.2653s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.8657s N, 29 49m 33.036s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.6224s N, 29 49m 32.8068s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.379s N, 29 49m 32.5775s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.1356s N, 29 49m 32.3483s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.8923s N, 29 49m 32.119s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.6489s N, 29 49m 31.8897s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.4055s N, 29 49m 31.6604s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.1622s N, 29 49m 31.4311s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.9188s N, 29 49m 31.2018s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.6755s N, 29 49m 30.9724s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.4321s N, 29 49m 30.7431s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.1888s N, 29 49m 30.5137s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.9455s N, 29 49m 30.2843s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.7021s N, 29 49m 30.0549s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.4588s N, 29 49m 29.8255s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.2155s N, 29 49m 29.596s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.9722s N, 29 49m 29.3666s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.7288s N, 29 49m 29.1371s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.4855s N, 29 49m 28.9075s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.2422s N, 29 49m 28.678s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.9989s N, 29 49m 28.4485s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.7556s N, 29 49m 28.2189s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.5124s N, 29 49m 27.9893s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.2691s N, 29 49m 27.7596s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.0745s N, 29 49m 27.5759s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.8312s N, 29 49m 27.3461s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.588s N, 29 49m 27.1163s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.3448s N, 29 49m 26.8864s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.1016s N, 29 49m 26.6564s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.8584s N, 29 49m 26.4263s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6153s N, 29 49m 26.196s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3723s N, 29 49m 25.9652s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1297s N, 29 49m 25.733s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0242s N, 29 49m 26.2259s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9241s N, 29 49m 26.7232s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8294s N, 29 49m 27.2246s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.74s N, 29 49m 27.7298s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6512s N, 29 49m 28.2355s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5625s N, 29 49m 28.7413s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4738s N, 29 49m 29.2471s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3852s N, 29 49m 29.7529s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2966s N, 29 49m 30.2587s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2079s N, 29 49m 30.7645s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1193s N, 29 49m 31.2703s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0307s N, 29 49m 31.7761s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.942s N, 29 49m 32.2819s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8534s N, 29 49m 32.7877s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7648s N, 29 49m 33.2936s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6762s N, 29 49m 33.7994s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5876s N, 29 49m 34.3052s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.499s N, 29 49m 34.811s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4104s N, 29 49m 35.3168s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3218s N, 29 49m 35.8227s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2332s N, 29 49m 36.3285s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1446s N, 29 49m 36.8343s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.056s N, 29 49m 37.3402s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9674s N, 29 49m 37.846s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8788s N, 29 49m 38.3518s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7902s N, 29 49m 38.8577s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7017s N, 29 49m 39.3635s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6131s N, 29 49m 39.8694s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5423s N, 29 49m 40.2741s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4537s N, 29 49m 40.7799s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3652s N, 29 49m 41.2858s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2767s N, 29 49m 41.7917s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1881s N, 29 49m 42.2975s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0996s N, 29 49m 42.8034s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0111s N, 29 49m 43.3093s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9226s N, 29 49m 43.8152s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8341s N, 29 49m 44.3211s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.7456s N, 29 49m 44.827s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.6572s N, 29 49m 45.3329s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.5687s N, 29 49m 45.8388s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4803s N, 29 49m 46.3448s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3919s N, 29 49m 46.8507s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3035s N, 29 49m 47.3567s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.2151s N, 29 49m 47.8627s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.1268s N, 29 49m 48.3687s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0385s N, 29 49m 48.8747s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9503s N, 29 49m 49.3808s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.8622s N, 29 49m 49.8869s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.7743s N, 29 49m 50.3933s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.698s N, 29 49m 50.2992s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.632s N, 29 49m 50.1783s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5766s N, 29 49m 50.0377s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5228s N, 29 49m 49.8948s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4699s N, 29 49m 49.7506s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4172s N, 29 49m 49.6061s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3645s N, 29 49m 49.4615s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3119s N, 29 49m 49.3169s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2592s N, 29 49m 49.1723s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2066s N, 29 49m 49.0276s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.154s N, 29 49m 48.8829s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.1014s N, 29 49m 48.7382s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0489s N, 29 49m 48.5935s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9963s N, 29 49m 48.4488s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9438s N, 29 49m 48.304s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.8912s N, 29 49m 48.1593s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'latitude'
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# #### Обеспечение ЦБ3: контроль доставки груза
#
# С помощью логики ограничителя выше мы реализовали обеспечение ЦБ1 (соблюдение заданных ограничений), однако есть ещё ЦБ3 (отгрузка только в заданной точке), не говоря о ЦБ2 (следование только по аутентичному маршруту).
#
# Для обеспечения ЦБ3 необходимо сделать следующее
# 1. изменить последовательность передачи команд, чтобы в блок управления грузовым отсеком (CargoBay) команды приходили только после проверки в Ограничителе
# 2. доработайте реализацию Ограничителя, чтобы команда на выгрузку передавалась в CargoBay только в конечной точке маршрута
# 3. продумайте логику работы блока безопасности, если система управления полностью перестанет работать (т.е. перестанет отправлять новые команды).
#
# Изменённая архитектура приведена на рис. 7.
#
# ![Ограничитель для обеспечения ЦБ1 и ЦБ3](images/ciac-arch-m312.png)
#
# Рис. 7. Ограничитель для обеспечения ЦБ1 и ЦБ3

# %%
# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку

# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# 3. создайте экземпляры изменённых классов и отправьте машинку по ранее предложенному маршруту


from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.event_types import Event

class CommunicationGateway(BaseCommunicationGateway):
    """Коммуникационный шлюз"""
    def _send_mission_to_consumers(self):
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        control_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(control_event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


class ControlSystem(BaseControlSystem):
    """Система управления"""
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        # Добавим создание очереди безопасности
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # Заменим destination на очередь безопасности
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                      )

        event_direction = Event(source=BaseControlSystem.event_source_name,
                          destination=safety_q_name,
                          operation="set_direction", parameters=direction
                          )

        # Положим события в очередь
        safety_q.put(event_speed)
        safety_q.put(event_direction)
    
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """

        # Добавим очередь безопасности для выполнения ЦБ
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=safety_q_name,
                      operation="lock_cargo",
                      parameters=None
                      )
        
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """

        # Добавим очередь безопасности для выполнения ЦБ
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=safety_q_name,
                      operation="release_cargo",
                      parameters=None
                      )
        
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

class NavigationSystem(BaseNavigationSystem):
    """Система навигации"""
    def _send_position_to_consumers(self):        
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        event = Event(source=BaseNavigationSystem.event_source_name,
                          destination=control_q_name,
                          operation="position_update", parameters=self._position
                          )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


# Создаем экземпляры измененных классов
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _emergency_stop(self):
        """Аварийная остановка"""
        # Устанавливаем скорость на 0
        self._speed = 0
        self._direction = 0
        
        # Записываем в лог сообщение об остановке и сообщаем координаты
        self._log_message(LOG_FAILURE, f'Произошла аварийная остановка. Текущие координаты: {self._position}.')
    
    def _calculate_direction(self):
        """Вычисляем направление движения к следующей точке маршрута"""
        cur_lat = radians(self._position.latitude)
        dest_lat = radians(self._route.next_point().latitude)
        long = radians(self._route.next_point().longitude - self._position.longitude)

        x = sin(long) * cos(dest_lat)
        y = cos(cur_lat) * sin(dest_lat) - sin(cur_lat) * cos(dest_lat) * cos(long)

        return (degrees(atan2(x, y)) + 360) % 360

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        
        # Если новое направление отличается от правильного по модулю более чем на 1 градус, не разрешаем изменение
        waypoint_direction = self._calculate_direction()
        if (abs(waypoint_direction - direction) >= 1):
            self._log_message(LOG_ERROR, f'Заданное направление {direction} отличается от верного.')
            self._emergency_stop()
            return

        self._direction = direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        
        # Находим ограничение по скорости
        speed_limit = self._route.calculate_speed()

        # Проверяем соответствие нового значения ограничениям
        if speed > speed_limit:
            # В случае некорректного значения не меняем скорость
            self._log_message(LOG_ERROR, f'Заданная скорость {speed} превышает ограничение {speed_limit}.')
        else:
            # В случае корректрного значения устанавливаем новую скорость
            self._speed = speed
        # Отправляем сообщение с новым значением скорости
        self._send_speed_to_consumers()


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)
    
    def _lock_cargo(self, _):
        # Передаем сообщения
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._log_message(LOG_DEBUG, "Передана команда на блокировку грузового отсека")

        cargo_q_name = CARGO_BAY_QUEUE_NAME

        event = Event(source=self.event_source_name,
                      destination=cargo_q_name,
                      operation="lock_cargo",
                      parameters=None
                      )
        
        cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)
        cargo_q.put(event)
    
    def _release_cargo(self, _):
        # Передаем сообщения
        self._log_message(LOG_DEBUG, "Передана команда на разблокировку грузового отсека")

        if self._route.route_finished:
            cargo_q_name = CARGO_BAY_QUEUE_NAME

            event = Event(source=self.event_source_name,
                        destination=cargo_q_name,
                        operation="release_cargo",
                        parameters=None
                        )
            
            cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)
            cargo_q.put(event)

            self._log_message(LOG_INFO, "Разблокирован грузовой отсек")
        else:
            self._log_message(LOG_DEBUG, "Маршрут не пройден, отказано в разблокировке грузового отсека.")
# Out:
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь communication

# %% [markdown]
# #### *Опциональное задание повышенной сложности* Обеспечение ЦБ2
#
# **Перед началом работы над этой задачей рекомендуем сохранить все текущие изменения в git репозитории (git commit, git push).**
#
# Напомним цель безопасности №2 (ЦБ2): "При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут"
#
# Обеспечение ЦБ2 потребует
# - внедрения механизма **контроля аутентичности маршрутного задания** (mission), а значит
# - помимо изменения **блока безопасности** (SafetyBlock), модификации
#   - системы **планирования задания** (MissionPlanner)
#   - **коммуникационного шлюза** (CommunicationGateway)
#   - и, возможно, **системы управления** (ControlSystem).
#
# Для решения этой задачи допустимо менять код соответствующих модулей в папке src.
#
# Возможным решением является внедрение механизма цифровой подписи, верификацией которой будет заниматься блок безопасности. В этой ситуации если коммуникационный шлюз (блок "1. Связь" на рис. 5 в модуле 1) оказался скомпрометированным и изменил маршрутное задание, оно не должно пройти проверку подлинности в блоке безопасности.
#
# **Рекомендуем эту задачу делать в последнюю очередь**, *после успешного выполнения модуля 4*, поскольку успешное выполнение модуля 4 принесёт больше баллов, чем внедрение цифровой подписи и обеспечение ЦБ2.
# К сведению, реализованные в этой версии киберпрепятствия не предполагают компрометацию маршрутного задания.
#
# Конечно, если будут решены все основные задачи и к тому же обеспечен контроль аутентичности маршрутного задания, такая работа с высокой вероятностью окажется лучшей.

# %%
# если вы собираетесь выполнить это задание, напишите в этой ячейке код выполнения изменённых блоков. 
# cам код допускается редактировать в папке src
# в случае успешной реализации машинка должна успешно пройти по маршруту, а в случае искажения маршрутного задания в блоке коммуникационного шлюза должна остаться на месте, 
# при этом именно блок безопасности должен заблокировать движение

# %% [markdown]
# ### Задание 3.2. Монитор безопасности

# %% [markdown]
# В текущей реализации каждый блок сам решает куда и какие данные ему отправлять. Это приемлемо, когда каждый блок рассматривается как благонадёжный. Однако нельзя исключать ситуацию успешной компрометации какого-либо из блоков (одного или нескольких), в результате которой злоумышленник может получить полный контроль над частью системы.
#
# В такой ситуации необходимо выстроить внутреннюю "поверхность защиты", частью этой системы уже является блок "Ограничитель", однако необходимо сделать так, чтобы соответствующие запросы проходили только через него, а не в обход.
#
# Для решения этой задачи необходимо добавить новый блок "Монитор безопасности". Его задача - обеспечить контроль направления информационных потоков, допустить передачу данных только между теми блоками и в тех направлениях, которые задуманы архитектором системы. Тогда, например, попытка передать команду из системы управления напрямую в сервоприводы в обход ограничителя будет заблокирована.
#
# Возможно, возникнет вопрос, а что помешает злоумышленнику отправить команду в обход этого монитора безопасности. В рамках этой учебной инфраструктуры особо ничего, однако при разработке реальной системы можно использовать специализированные микроядерные операционные системы, такие как, например, KasperskyOS, которые обеспечат обязательное вовлечение монитора безопасности в контроль взаимодействия между блоками.
#
# Архитектура системы для решения задачи 3.2 должна выглядеть как на рис.8:
#
# ![Архитектура системы с монитором безопасности](images/ciac-arch-m32.png)
#
# Рис. 8. Архитектура бортовых систем с монитором безопасности

# %% [markdown]
# Базовый класс модуля безопасности находится в файле src/security_monitor.py, его менять не нужно.
#
# В следующей ячейке находится реализация класса SecurityMonitor

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO, SAFETY_BLOCK_QUEUE_NAME, NAVIGATION_QUEUE_NAME
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [

            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='release_cargo'
            ),
             SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_speed'
            ),
             SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='release_cargo'
            )

        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Обратите внимание на этот код:
# ```python
#     def _init_set_security_policies(self):
#         """ инициализация политик безопасности """
#         default_policies = [
#             SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
#         ]
#         self.set_security_policies(policies=default_policies)
# ```
#
# В нём инициализируется политика безопасности, разрешающая запрос set_mission от коммуникационного шлюза в систему управления.
#
# Код политики безопасности в строка 6-9:
# ```python
# SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
# ```
#
# Шаблон политики безопасности описан в файле src/security_policy_type.py:
# ```python
# @dataclass
# class SecurityPolicy:
#     """ политика безопасности """
#     source: str         # отправитель запроса
#     destination: str    # получатель
#     operation: str      # запрашиваемая операция
#
# ```
#
# По аналогии в методе _init_set_security_policies допишите другие политики безопасности, чтобы разрешить взаимодействия согласно диаграмме на рис.7. выше.

# %% [markdown]
# Теперь необходимо изменить взаимодействие между блоками так, чтобы оно всегда проходило через монитор безопасности. Для этого потребуется изменить соответствующие реализации внутренних блоков.

# %% [markdown]
# Ниже пример для блока навигации. Обратите внимание на выделенные строки и комментарии.
#
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         # событие для системы управления,
#         # поэтому в destination указываем CONTROL_SYSTEM_QUEUE_NAME
#         event = Event(source=self.event_source_name,
# >>>                      destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         # но событие отправляем сначала на проверку в монитор безопасности,
#         # поэтому используем очередь с именем SECURITY_MONITOR_QUEUE_NAME
# >>>        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#         # а в систему управления наше событие монитор безопасности отправит сам, если найдёт разрешающую эту операцию политику безопасности
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         event = Event(source=self.event_source_name,
#                       destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)

# %% [markdown]
# В файле tests/module/test_security_monitor.py можно увидеть тест логики работы монитора безопасности. Запустить его можно следующей командой:

# %%
# !pytest -svk security_monitor
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.12, pytest-8.3.4, pluggy-1.5.0 -- /bin/python3
# cachedir: .pytest_cache
# rootdir: /home/eldar/Документы/Uni/Systems/cyberimmune-autonomy--chvt-preview
# configfile: pytest.ini
# testpaths: tests
# collected 1 item
#
# tests/module/test_security_monitor.py::test_security_policies [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='control', operation='set_mission', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='cargo', operation='release_cargo', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# PASSED
#
# ============================== 1 passed in 0.02s ===============================

# %% [markdown]
# В одном кодовом блоке ниже (или нескольких - как будет удобнее)  сделайте следующее
#
# 1. Измените реализацию монитора безопасности в части правил проверки передаваемых сообщений в мониторе безопасности
# 2. Измените параметры отправки сообщений между элементами бортовых систем (блоками 1-7), чтобы они всегда отправлялись в очередь монитора безопасности (отправитель и получатель при этом не меняются)
# 3. После всех изменений убедитесь в том, что машинка по-прежнему успешно выполняет маршрутное задание и доставляет груз
# 4. Дополнительные баллы принесут автоматические тесты правил безопасности в файле tests/module/test_security_monitor.py - можно проверить, что все новые политики работают как ожидаются, а недопустимые взаимодействия (т.е. таких стрелок нет на рис. 8) блокируются

# %%
# добавьте изменения сюда

from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.event_types import Event

class CommunicationGateway(BaseCommunicationGateway):
    """Коммуникационный шлюз"""
    def _send_mission_to_consumers(self):
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        control_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(control_event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


class ControlSystem(BaseControlSystem):
    """Система управления"""
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        # Добавим создание очереди безопасности
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # Заменим destination на очередь безопасности
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                      )

        event_direction = Event(source=BaseControlSystem.event_source_name,
                          destination=safety_q_name,
                          operation="set_direction", parameters=direction
                          )

        # Положим события в очередь
        safety_q.put(event_speed)
        safety_q.put(event_direction)
    
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """

        # Добавим очередь безопасности для выполнения ЦБ
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=safety_q_name,
                      operation="lock_cargo",
                      parameters=None
                      )
        
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """

        # Добавим очередь безопасности для выполнения ЦБ
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=safety_q_name,
                      operation="release_cargo",
                      parameters=None
                      )
        
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

class NavigationSystem(BaseNavigationSystem):
    """Система навигации"""
    def _send_position_to_consumers(self):        
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        event = Event(source=BaseNavigationSystem.event_source_name,
                          destination=control_q_name,
                          operation="position_update", parameters=self._position
                          )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _emergency_stop(self):
        """Аварийная остановка"""
        # Устанавливаем скорость на 0
        self._speed = 0
        self._direction = 0
        
        # Записываем в лог сообщение об остановке и сообщаем координаты
        self._log_message(LOG_FAILURE, f'Произошла аварийная остановка. Текущие координаты: {self._position}.')
    
    def _calculate_direction(self):
        """Вычисляем направление движения к следующей точке маршрута"""
        cur_lat = radians(self._position.latitude)
        dest_lat = radians(self._route.next_point().latitude)
        long = radians(self._route.next_point().longitude - self._position.longitude)

        x = sin(long) * cos(dest_lat)
        y = cos(cur_lat) * sin(dest_lat) - sin(cur_lat) * cos(dest_lat) * cos(long)

        return (degrees(atan2(x, y)) + 360) % 360

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        
        # Если новое направление отличается от правильного по модулю более чем на 1 градус, не разрешаем изменение
        waypoint_direction = self._calculate_direction()
        if (abs(waypoint_direction - direction) >= 1):
            self._log_message(LOG_ERROR, f'Заданное направление {direction} отличается от верного.')
            self._emergency_stop()
            return

        self._direction = direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        
        # Находим ограничение по скорости
        speed_limit = self._route.calculate_speed()

        # Проверяем соответствие нового значения ограничениям
        if speed > speed_limit:
            # В случае некорректного значения не меняем скорость
            self._log_message(LOG_ERROR, f'Заданная скорость {speed} превышает ограничение {speed_limit}.')
        else:
            # В случае корректрного значения устанавливаем новую скорость
            self._speed = speed
        # Отправляем сообщение с новым значением скорости
        self._send_speed_to_consumers()


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)
    
    def _lock_cargo(self, _):
        # Передаем сообщения
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._log_message(LOG_DEBUG, "Передана команда на блокировку грузового отсека")

        cargo_q_name = CARGO_BAY_QUEUE_NAME

        event = Event(source=self.event_source_name,
                      destination=cargo_q_name,
                      operation="lock_cargo",
                      parameters=None
                      )
        
        cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)
        cargo_q.put(event)
    
    def _release_cargo(self, _):
        # Передаем сообщения
        self._log_message(LOG_DEBUG, "Передана команда на разблокировку грузового отсека")

        if self._route.route_finished:
            cargo_q_name = CARGO_BAY_QUEUE_NAME

            event = Event(source=self.event_source_name,
                        destination=cargo_q_name,
                        operation="release_cargo",
                        parameters=None
                        )
            
            cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)
            cargo_q.put(event)

            self._log_message(LOG_INFO, "Разблокирован грузовой отсек")
        else:
            self._log_message(LOG_DEBUG, "Маршрут не пройден, отказано в разблокировке грузового отсека.")


from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO, SAFETY_BLOCK_QUEUE_NAME, NAVIGATION_QUEUE_NAME
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [

            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='release_cargo'
            ),
             SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_speed'
            ),
             SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='release_cargo'
            )

        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized


# Создаем экземпляры измененных классов
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)

# создадим все остальные компоненты

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(130)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1974s N, 29 50m 3.90055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2279s N, 29 50m 3.73262s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2585s N, 29 50m 3.56468s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.289s N, 29 50m 3.39675s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3134s N, 29 50m 3.2624s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3439s N, 29 50m 3.09445s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3744s N, 29 50m 2.92649s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4049s N, 29 50m 2.75852s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4353s N, 29 50m 2.59051s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3547s N, 29 50m 2.51211s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2706s N, 29 50m 2.44944s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1839s N, 29 50m 2.40313s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0968s N, 29 50m 2.36032s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0094s N, 29 50m 2.31989s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9218s N, 29 50m 2.28024s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8343s N, 29 50m 2.24108s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7467s N, 29 50m 2.20214s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6591s N, 29 50m 2.16334s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5714s N, 29 50m 2.12464s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.4838s N, 29 50m 2.08601s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.5895s N, 29 50m 1.59325s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6968s N, 29 50m 1.10191s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8058s N, 29 50m 0.61199s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.9148s N, 29 50m 0.122127s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.0239s N, 29 49m 59.6323s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1329s N, 29 49m 59.1425s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.242s N, 29 49m 58.6526s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.351s N, 29 49m 58.1628s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4601s N, 29 49m 57.6729s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.5691s N, 29 49m 57.1831s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6782s N, 29 49m 56.6932s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.7872s N, 29 49m 56.2033s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.8962s N, 29 49m 55.7135s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.00526344s N, 29 49m 55.2236s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.114284s N, 29 49m 54.7337s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.2233s N, 29 49m 54.2439s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.33231s N, 29 49m 53.754s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.441315s N, 29 49m 53.2641s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.550315s N, 29 49m 52.7742s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.659309s N, 29 49m 52.2843s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.768297s N, 29 49m 51.7944s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.87728s N, 29 49m 51.3045s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.964461s N, 29 49m 50.9125s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.07343s N, 29 49m 50.4226s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.1824s N, 29 49m 49.9327s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.29135s N, 29 49m 49.4427s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.40031s N, 29 49m 48.9528s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.50925s N, 29 49m 48.4628s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.61818s N, 29 49m 47.9729s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.72711s N, 29 49m 47.4829s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.83603s N, 29 49m 46.9929s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.94494s N, 29 49m 46.503s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.05384s N, 29 49m 46.013s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.16273s N, 29 49m 45.523s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.27162s N, 29 49m 45.033s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.38049s N, 29 49m 44.5429s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.48934s N, 29 49m 44.0529s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.59819s N, 29 49m 43.5629s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.70702s N, 29 49m 43.0728s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.81584s N, 29 49m 42.5828s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.92464s N, 29 49m 42.0927s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.03342s N, 29 49m 41.6026s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.14219s N, 29 49m 41.1125s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.25093s N, 29 49m 40.6223s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.35964s N, 29 49m 40.1322s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.46832s N, 29 49m 39.642s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.57697s N, 29 49m 39.1518s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.68556s N, 29 49m 38.6615s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.79409s N, 29 49m 38.1712s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.90252s N, 29 49m 37.6808s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 4.01075s N, 29 49m 37.1902s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 4.11827s N, 29 49m 36.699s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.85462s N, 29 49m 36.808s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.59268s N, 29 49m 36.9322s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.33258s N, 29 49m 37.0708s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.07263s N, 29 49m 37.2106s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.81275s N, 29 49m 37.3509s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.55289s N, 29 49m 37.4913s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.29303s N, 29 49m 37.6317s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.08514s N, 29 49m 37.7441s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.82528s N, 29 49m 37.8845s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.56543s N, 29 49m 38.025s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.30557s N, 29 49m 38.1654s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.04572s N, 29 49m 38.3059s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.785872s N, 29 49m 38.4464s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.526023s N, 29 49m 38.5869s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.266176s N, 29 49m 38.7275s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.00633134s N, 29 49m 38.868s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.7465s N, 29 49m 39.0086s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.4866s N, 29 49m 39.1491s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.2268s N, 29 49m 39.2897s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.967s N, 29 49m 39.4304s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.7071s N, 29 49m 39.571s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.4473s N, 29 49m 39.7117s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.1875s N, 29 49m 39.8524s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.9277s N, 29 49m 39.9931s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.6679s N, 29 49m 40.1339s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.4081s N, 29 49m 40.2747s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.1483s N, 29 49m 40.4156s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.8885s N, 29 49m 40.5566s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.6287s N, 29 49m 40.6977s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.369s N, 29 49m 40.839s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.1093s N, 29 49m 40.9811s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.875s N, 29 49m 40.7172s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.6562s N, 29 49m 40.405s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.4596s N, 29 49m 40.039s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.2718s N, 29 49m 39.655s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.0925s N, 29 49m 39.2552s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.9194s N, 29 49m 38.8449s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7537s N, 29 49m 38.4226s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6016s N, 29 49m 37.9806s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3496s N, 29 49m 37.7918s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0932s N, 29 49m 37.6276s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8324s N, 29 49m 37.495s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5707s N, 29 49m 37.3687s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.3084s N, 29 49m 37.2472s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.046s N, 29 49m 37.1272s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.7834s N, 29 49m 37.0083s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.5733s N, 29 49m 36.9135s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.3107s N, 29 49m 36.7953s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.048s N, 29 49m 36.6774s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.7853s N, 29 49m 36.5596s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.5226s N, 29 49m 36.442s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.278s N, 29 49m 36.2182s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.0339s N, 29 49m 35.9922s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.7903s N, 29 49m 35.7637s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.5467s N, 29 49m 35.5352s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.3032s N, 29 49m 35.3066s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.0597s N, 29 49m 35.0779s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.8162s N, 29 49m 34.8493s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.5727s N, 29 49m 34.6207s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.3292s N, 29 49m 34.392s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.0856s N, 29 49m 34.1633s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.8421s N, 29 49m 33.9347s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.5986s N, 29 49m 33.706s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.3551s N, 29 49m 33.4773s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.1116s N, 29 49m 33.2486s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.8681s N, 29 49m 33.0199s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.6246s N, 29 49m 32.7912s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.3811s N, 29 49m 32.5624s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.1376s N, 29 49m 32.3337s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.8941s N, 29 49m 32.1049s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.6507s N, 29 49m 31.8762s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.4072s N, 29 49m 31.6474s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.1637s N, 29 49m 31.4186s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.9202s N, 29 49m 31.1898s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.6767s N, 29 49m 30.961s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.4333s N, 29 49m 30.7322s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.1898s N, 29 49m 30.5033s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.9463s N, 29 49m 30.2744s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.7029s N, 29 49m 30.0456s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.4594s N, 29 49m 29.8167s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.216s N, 29 49m 29.5878s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.9725s N, 29 49m 29.3589s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.7291s N, 29 49m 29.1299s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.4856s N, 29 49m 28.901s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.2422s N, 29 49m 28.672s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.0475s N, 29 49m 28.4887s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.8041s N, 29 49m 28.2597s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.5607s N, 29 49m 28.0306s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.3173s N, 29 49m 27.8015s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.0739s N, 29 49m 27.5723s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.8305s N, 29 49m 27.343s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.5871s N, 29 49m 27.1137s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.3438s N, 29 49m 26.8844s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.1005s N, 29 49m 26.6549s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.8572s N, 29 49m 26.4252s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.614s N, 29 49m 26.1954s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3709s N, 29 49m 25.9651s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1281s N, 29 49m 25.7334s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0227s N, 29 49m 26.2263s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9226s N, 29 49m 26.7236s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8279s N, 29 49m 27.225s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7385s N, 29 49m 27.7303s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6495s N, 29 49m 28.2358s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5609s N, 29 49m 28.7417s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4722s N, 29 49m 29.2475s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3836s N, 29 49m 29.7533s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.295s N, 29 49m 30.2591s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2064s N, 29 49m 30.765s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1178s N, 29 49m 31.2708s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0292s N, 29 49m 31.7766s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9406s N, 29 49m 32.2824s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.852s N, 29 49m 32.7883s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7635s N, 29 49m 33.2941s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6749s N, 29 49m 33.8s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5863s N, 29 49m 34.3058s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4977s N, 29 49m 34.8117s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4092s N, 29 49m 35.3175s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3206s N, 29 49m 35.8234s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.232s N, 29 49m 36.3292s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1435s N, 29 49m 36.8351s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0549s N, 29 49m 37.3409s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9841s N, 29 49m 37.7456s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8955s N, 29 49m 38.2515s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.807s N, 29 49m 38.7573s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7185s N, 29 49m 39.2632s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6299s N, 29 49m 39.7691s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5414s N, 29 49m 40.275s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4529s N, 29 49m 40.7808s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3644s N, 29 49m 41.2867s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2759s N, 29 49m 41.7926s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1874s N, 29 49m 42.2985s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0989s N, 29 49m 42.8044s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0104s N, 29 49m 43.3103s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.922s N, 29 49m 43.8162s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8335s N, 29 49m 44.3222s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.7451s N, 29 49m 44.8281s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.6567s N, 29 49m 45.334s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.5683s N, 29 49m 45.84s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4799s N, 29 49m 46.346s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3915s N, 29 49m 46.8519s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3031s N, 29 49m 47.3579s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.2148s N, 29 49m 47.8639s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.1265s N, 29 49m 48.37s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0383s N, 29 49m 48.876s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9501s N, 29 49m 49.3821s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.862s N, 29 49m 49.8883s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.7741s N, 29 49m 50.3946s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6979s N, 29 49m 50.3005s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6318s N, 29 49m 50.1795s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5765s N, 29 49m 50.0389s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5228s N, 29 49m 49.8959s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4699s N, 29 49m 49.7517s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4171s N, 29 49m 49.6072s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3645s N, 29 49m 49.4626s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3119s N, 29 49m 49.3179s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2593s N, 29 49m 49.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2067s N, 29 49m 49.0285s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.1541s N, 29 49m 48.8838s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.1121s N, 29 49m 48.768s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0595s N, 29 49m 48.6233s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.007s N, 29 49m 48.4785s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9545s N, 29 49m 48.3338s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Разблокирован грузовой отсек
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.902s N, 29 49m 48.189s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'latitude'
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# На этом модуль 3 завершён!
#
# Если у вас всё получилось, то вы создали защищённую автономную машинку - ещё уже не так-то просто использовать для нанесения критического ущерба людям и имуществу, потому что самые критические режимы проверяются вашим Ограничителем, а если вы ещё и внедрили Монитор Безопасности, то теперь злоумышленнику гораздо сложнее атаковать внутренние блоки, даже если он смог проникнуть в какую-то бортовую систему или внедрить вредоносный код.
#
# Осталось проверить эффективность получившейся защиты на полной трассе - в этом и заключается модуль 4 задания, для перехода к которому нужно открыть блокнот с именем cyberimmunity--autonomous-car-m4. Успеха!
