# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 4
#
# ## О документе
#
# Версия 1.03
#
# Модуль 4 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 4. Следование по трассе с киберпрепятствиями
#
# Для успешного выполнения этого задания необходимое активировать специальный режим работы виртуальной машинки - в рамках этого задания можно менять только блоки, отвечающие за безопасность (ограничитель, монитор безопасности), **другие блоки менять запрещено**.
#
# При прохождении маршрута будут имитироваться атаки со стороны злоумышленников, которые будут пытаться нарушить цели безопасности. Важно, чтобы им это не удалось.

# %% [markdown]
# 1. Запустите свою машинку и убедитесь, что она проходит всю трассу без нарушений ограничений скорости. При необходимости измените логику работы блока безопасности
# 2. Добавьте контроль доставки груза в модуле SafetyBlock - убедитесь, что груз доставляется до конечной точки маршрута.
# 3. Если в модуле 3 вы реализовали монитор безопасности - не забудьте его перенести в этот модуль, это принесёт дополнительные баллы!

# %% [markdown]
# Активация киберпрепятствий в системе управления:
#
# после инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# В этом блоке добавьте все ваши реализации изменённых бортовых систем

# %%
# добавьте изменения сюда

from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.event_types import Event
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy
from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO, SAFETY_BLOCK_QUEUE_NAME, NAVIGATION_QUEUE_NAME
from src.safety_block import BaseSafetyBlock
from src.config import LOG_FAILURE, LOG_DEBUG
from math import radians, sin, cos, degrees, atan2


class CommunicationGateway(BaseCommunicationGateway):
    """Коммуникационный шлюз"""
    def _send_mission_to_consumers(self):
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        control_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(control_event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


class ControlSystem(BaseControlSystem):
    """Система управления"""
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        # Добавим создание очереди безопасности
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # Заменим destination на очередь безопасности
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                      )

        event_direction = Event(source=BaseControlSystem.event_source_name,
                          destination=safety_q_name,
                          operation="set_direction", parameters=direction
                          )

        # Положим события в очередь
        safety_q.put(event_speed)
        safety_q.put(event_direction)
    
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """

        # Добавим очередь безопасности для выполнения ЦБ
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=safety_q_name,
                      operation="lock_cargo",
                      parameters=None
                      )
        
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """

        # Добавим очередь безопасности для выполнения ЦБ
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                      destination=safety_q_name,
                      operation="release_cargo",
                      parameters=None
                      )
        
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """Система навигации"""
    def _send_position_to_consumers(self):        
        # Добавим получение имени очереди безопасности
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # Добавим создание события безопасности
        event = Event(source=BaseNavigationSystem.event_source_name,
                          destination=control_q_name,
                          operation="position_update", parameters=self._position
                          )
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                      )

        # Добавим добавление нового события в очередь безопасности
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(safety_event)


class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _emergency_stop(self):
        """Аварийная остановка"""
        # Устанавливаем скорость на 0
        self._speed = 0
        self._direction = 0
        
        # Записываем в лог сообщение об остановке и сообщаем координаты
        self._log_message(LOG_FAILURE, f'Произошла аварийная остановка. Текущие координаты: {self._position}.')
    
    def _calculate_direction(self):
        """Вычисляем направление движения к следующей точке маршрута"""
        if not self._route.next_point():
            # Предусмотрим нахождение в последней точке маршрута
            return self._direction
        cur_lat = radians(self._position.latitude)
        dest_lat = radians(self._route.next_point().latitude)
        long = radians(self._route.next_point().longitude - self._position.longitude)

        x = sin(long) * cos(dest_lat)
        y = cos(cur_lat) * sin(dest_lat) - sin(cur_lat) * cos(dest_lat) * cos(long)

        return (degrees(atan2(x, y)) + 360) % 360

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        
        # Если новое направление отличается от правильного по модулю более чем на 1 градус, не разрешаем изменение
        waypoint_direction = self._calculate_direction()
        if (abs(waypoint_direction - direction) >= 1):
            self._log_message(LOG_ERROR, f'Заданное направление {direction} отличается от верного.')
            self._direction = waypoint_direction
            self._send_direction_to_consumers()
            # self._emergency_stop()
            return

        self._direction = direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        
        # Находим ограничение по скорости
        speed_limit = self._route.calculate_speed()

        # Проверяем соответствие нового значения ограничениям
        if speed > speed_limit:
            # В случае некорректного значения не меняем скорость
            self._log_message(LOG_ERROR, f'Заданная скорость {speed} превышает ограничение {speed_limit}.')
        else:
            # В случае корректрного значения устанавливаем новую скорость
            self._speed = speed
        # Отправляем сообщение с новым значением скорости
        self._send_speed_to_consumers()


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)
    
    def _lock_cargo(self, _):
        # Передаем сообщения
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._log_message(LOG_DEBUG, "Передана команда на блокировку грузового отсека")

        cargo_q_name = CARGO_BAY_QUEUE_NAME

        event = Event(source=self.event_source_name,
                      destination=cargo_q_name,
                      operation="lock_cargo",
                      parameters=None
                      )
        
        cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)
        cargo_q.put(event)
    
    def _release_cargo(self, _):
        # Передаем сообщения
        self._log_message(LOG_DEBUG, "Передана команда на разблокировку грузового отсека")

        if self._route.route_finished:
            cargo_q_name = CARGO_BAY_QUEUE_NAME

            event = Event(source=self.event_source_name,
                        destination=cargo_q_name,
                        operation="release_cargo",
                        parameters=None
                        )
            
            cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)
            cargo_q.put(event)

            self._log_message(LOG_INFO, "Разблокирован грузовой отсек")
        else:
            self._log_message(LOG_DEBUG, "Маршрут не пройден, отказано в разблокировке грузового отсека.")    
    

class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [

            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='release_cargo'
            ),
             SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_speed'
            ),
             SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='release_cargo'
            )

        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m4"

# %% [markdown]
# В следующем блоке измените маршрут на ваш, его можно скопировать из модуля 2.
#
# Для проверки работы систем безопасности будут активированы киберпрепятствия
#
# ```python
# control_system.enable_critical_surprises()
# ```

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep

from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser
from src.mission_type import GeoSpecificSpeedLimit


# возьмём маршрут от аэропорта Пулково до станции метро Купчино
wpl_file = "terminal.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()

# Считаем, что у Пулково можно ехать до 60, по трассе - до 110, по городу - до 60
speed_limits = [
    GeoSpecificSpeedLimit(0, 60),
    GeoSpecificSpeedLimit(19, 110),
    GeoSpecificSpeedLimit(26, 60),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 


# создание блоков передачи данных в СУПА
if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

# создание основных функциональных блоков
mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)     
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)


# сборка всех запускаемых блоков в одном "кузове"
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

# запуск всех блоков
system_components.start()

# ограничение поездки по времени
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(630)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 15:15:23.883893
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][CONTROL] новая скорость 60 (была 0)
# [ИНФО][CONTROL] новое направление 194 (было 0)
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.7012s N, 30 16m 22.1988s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.7012s N, 30 16m 22.1988s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.7012s N, 30 16m 22.1988s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.7012s N, 30 16m 22.1988s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.4405s N, 30 16m 22.0647s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.1799s N, 30 16m 21.9307s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.9713s N, 30 16m 21.8235s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.7107s N, 30 16m 21.6894s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.45s N, 30 16m 21.5553s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.1893s N, 30 16m 21.4212s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.9287s N, 30 16m 21.2871s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.668s N, 30 16m 21.1529s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.4074s N, 30 16m 21.0188s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.1467s N, 30 16m 20.8846s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.8861s N, 30 16m 20.7503s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.6254s N, 30 16m 20.616s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.3648s N, 30 16m 20.4817s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.1042s N, 30 16m 20.3473s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 322 (было 194)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.8436s N, 30 16m 20.2128s E
# [ОШИБКА][SAFETY] Заданное направление 322.65085891476497 отличается от верного.
# [ИНФО][CONTROL] новое направление 319 (было 322)
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.583s N, 30 16m 20.0781s E
# [ОШИБКА][SAFETY] Заданное направление 319.3871057625572 отличается от верного.
# [ИНФО][CONTROL] новое направление 315 (было 319)
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.3225s N, 30 16m 19.943s E
# [ОШИБКА][SAFETY] Заданное направление 315.84126715885634 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.1084s N, 30 16m 20.2672s E
# [ОШИБКА][SAFETY] Заданное направление 315.28507548676635 отличается от верного.
# [ИНФО][CONTROL] новое направление 314 (было 315)
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.904s N, 30 16m 20.615s E
# [ОШИБКА][SAFETY] Заданное направление 314.91822969506853 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.7108s N, 30 16m 20.9873s E
# [ОШИБКА][SAFETY] Заданное направление 314.8239946211338 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.5195s N, 30 16m 21.3632s E
# [ОШИБКА][SAFETY] Заданное направление 314.7692760652983 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.3293s N, 30 16m 21.7416s E
# [ОШИБКА][SAFETY] Заданное направление 314.74555025374775 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.1395s N, 30 16m 22.1206s E
# [ОШИБКА][SAFETY] Заданное направление 314.7282186613759 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.9499s N, 30 16m 22.5s E
# [ОШИБКА][SAFETY] Заданное направление 314.7140548759297 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.7603s N, 30 16m 22.8795s E
# [ОШИБКА][SAFETY] Заданное направление 314.69900617806604 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.5708s N, 30 16m 23.2591s E
# [ОШИБКА][SAFETY] Заданное направление 314.6809694012055 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.3813s N, 30 16m 23.6388s E
# [ОШИБКА][SAFETY] Заданное направление 314.6562710867731 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.1919s N, 30 16m 24.0186s E
# [ОШИБКА][SAFETY] Заданное направление 314.61661659977017 отличается от верного.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.0026s N, 30 16m 24.3986s E
# [ОШИБКА][SAFETY] Заданное направление 314.5298559990988 отличается от верного.
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 160 (была 60)
# [ИНФО][CONTROL] новое направление 82 (было 314)
# [ИНФО][SAFETY] сегмент пройден
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8133s N, 30 16m 24.7787s E
# [ИНФО][CONTROL] новое направление 81 (было 82)
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.6242s N, 30 16m 25.159s E
# [ИНФО][CONTROL] новое направление 80 (было 81)
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.4353s N, 30 16m 25.5399s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.4709s N, 30 16m 26.0696s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.5104s N, 30 16m 26.5982s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.5537s N, 30 16m 27.1256s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.5971s N, 30 16m 27.6529s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.6406s N, 30 16m 28.1802s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.6842s N, 30 16m 28.7075s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.7277s N, 30 16m 29.2348s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.7712s N, 30 16m 29.7621s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8148s N, 30 16m 30.2895s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8583s N, 30 16m 30.8168s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.9018s N, 30 16m 31.3441s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.9453s N, 30 16m 31.8714s E
# [ОШИБКА][SAFETY] Заданная скорость 160 превышает ограничение 60.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.

# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 47m 26.6659s N, 30 19m 22.3816s E
# [ИНФО][CONTROL] новое направление 54 (было 56)
# [ИНФО][SAFETY] текущие координаты: 59 47m 26.7058s N, 30 19m 22.91s E
# [ИНФО][CONTROL] новое направление 53 (было 54)
# [ИНФО][SAFETY] текущие координаты: 59 47m 26.7455s N, 30 19m 23.4384s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 26.8944s N, 30 19m 23.8835s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 27.0489s N, 30 19m 24.3211s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 27.2095s N, 30 19m 24.75s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 27.3708s N, 30 19m 25.1778s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 27.5326s N, 30 19m 25.6048s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 27.6945s N, 30 19m 26.0318s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 27.8564s N, 30 19m 26.4587s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 28.0183s N, 30 19m 26.8856s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 28.1801s N, 30 19m 27.3126s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 28.342s N, 30 19m 27.7396s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 28.5038s N, 30 19m 28.1666s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 28.6656s N, 30 19m 28.5937s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 28.795s N, 30 19m 28.9354s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 28.9568s N, 30 19m 29.3626s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 29.1184s N, 30 19m 29.7899s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 39 (было 53)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 47m 29.28s N, 30 19m 30.2173s E
# [ИНФО][CONTROL] новое направление 38 (было 39)
# [ИНФО][SAFETY] текущие координаты: 59 47m 29.4414s N, 30 19m 30.6449s E
# [ИНФО][CONTROL] новое направление 37 (было 38)
# [ИНФО][SAFETY] текущие координаты: 59 47m 29.6026s N, 30 19m 31.0729s E
# [ИНФО][CONTROL] новое направление 36 (было 37)
# [ИНФО][SAFETY] текущие координаты: 59 47m 29.8021s N, 30 19m 31.4279s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 30.0131s N, 30 19m 31.7597s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 30.2268s N, 30 19m 32.0847s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 30.4418s N, 30 19m 32.4065s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 30.6572s N, 30 19m 32.7271s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 30.8727s N, 30 19m 33.0474s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 31.0883s N, 30 19m 33.3675s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 31.3039s N, 30 19m 33.6876s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 31.5195s N, 30 19m 34.0077s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 31.7351s N, 30 19m 34.3278s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 31.9507s N, 30 19m 34.648s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 32.1663s N, 30 19m 34.9682s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 32.3818s N, 30 19m 35.2886s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 32.5972s N, 30 19m 35.609s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 18 (было 36)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 47m 32.8126s N, 30 19m 35.9296s E
# [ИНФО][CONTROL] новое направление 17 (было 18)
# [ИНФО][SAFETY] текущие координаты: 59 47m 33.028s N, 30 19m 36.2505s E
# [ИНФО][CONTROL] новое направление 16 (было 17)
# [ИНФО][SAFETY] текущие координаты: 59 47m 33.2431s N, 30 19m 36.5718s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 33.4983s N, 30 19m 36.7425s E
# [ИНФО][CONTROL] новое направление 15 (было 16)
# [ИНФО][SAFETY] текущие координаты: 59 47m 33.7551s N, 30 19m 36.9034s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 34.0136s N, 30 19m 37.0528s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 34.2723s N, 30 19m 37.2008s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 34.5312s N, 30 19m 37.3478s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 34.7901s N, 30 19m 37.4946s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.0491s N, 30 19m 37.6413s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.308s N, 30 19m 37.7881s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.5669s N, 30 19m 37.9348s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.8258s N, 30 19m 38.0816s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.0847s N, 30 19m 38.2284s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.3436s N, 30 19m 38.3753s E
# [ИНФО][CONTROL] новое направление 16 (было 15)
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.6025s N, 30 19m 38.5222s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.8614s N, 30 19m 38.6692s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 356 (было 16)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.1203s N, 30 19m 38.8164s E
# [ИНФО][CONTROL] новое направление 355 (было 356)
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.3791s N, 30 19m 38.9637s E
# [ИНФО][CONTROL] новое направление 353 (было 355)
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.6379s N, 30 19m 39.1117s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.9066s N, 30 19m 39.0781s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.1749s N, 30 19m 39.0329s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.4426s N, 30 19m 38.9748s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.7102s N, 30 19m 38.9148s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.9777s N, 30 19m 38.8537s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.2452s N, 30 19m 38.7923s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.5127s N, 30 19m 38.7308s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39
E
# [ИНФО][SAFETY] текущие координаты: 59 49m 36.8153s N, 30 22m 33.9852s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 37.0654s N, 30 22m 33.7869s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 37.3155s N, 30 22m 33.5887s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 37.5656s N, 30 22m 33.3904s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 37.8156s N, 30 22m 33.1921s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 38.0657s N, 30 22m 32.9937s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 38.3158s N, 30 22m 32.7953s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 38.5658s N, 30 22m 32.5969s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 38.8159s N, 30 22m 32.3984s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 39.0659s N, 30 22m 32.1999s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 39.3159s N, 30 22m 32.0012s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 39.5659s N, 30 22m 31.8025s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 344 (было 338)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 49m 39.8159s N, 30 22m 31.6036s E
# [ИНФО][CONTROL] новое направление 345 (было 344)
# [ИНФО][SAFETY] текущие координаты: 59 49m 40.0658s N, 30 22m 31.4045s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 40.3156s N, 30 22m 31.2048s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 40.5755s N, 30 22m 31.0647s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 40.8357s N, 30 22m 30.9268s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 41.0962s N, 30 22m 30.7913s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 41.3567s N, 30 22m 30.656s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 41.6172s N, 30 22m 30.5207s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 41.8778s N, 30 22m 30.3855s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 42.0862s N, 30 22m 30.2773s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 42.3467s N, 30 22m 30.1421s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 42.6072s N, 30 22m 30.0069s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 42.8678s N, 30 22m 29.8716s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 43.1283s N, 30 22m 29.7363s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 43.3888s N, 30 22m 29.6011s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 43.6493s N, 30 22m 29.4658s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 43.9098s N, 30 22m 29.3305s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 44.1704s N, 30 22m 29.1951s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 44.4309s N, 30 22m 29.0598s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 44.6914s N, 30 22m 28.9244s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 44.9519s N, 30 22m 28.789s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 45.2124s N, 30 22m 28.6536s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 45.4729s N, 30 22m 28.5181s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 45.7334s N, 30 22m 28.3826s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 45.9939s N, 30 22m 28.2471s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 46.2544s N, 30 22m 28.1115s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 46.5148s N, 30 22m 27.9759s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 46.7753s N, 30 22m 27.8401s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 15:25:07.221798
# [ИНФО][CONTROL] новая скорость 0.0 (была 60)
# [ИНФО][CONTROL] новое направление 0 (было 345)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Разблокирован грузовой отсек
# [ИНФО][SAFETY] текущие координаты: 59 49m 47.0357s N, 30 22m 27.704s E
# [ОШИБКА][SAFETY] Заданное направление 0.0 отличается от верного.
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# Убедитесь, что
# 1. ваша машинка успешно прошла весь заданный маршрут
# 2. не превысила ограничения скорости
# 3. успешно доставила груз
#
# Если всё так - поздравляем, вы справились с заданием! Обязательно зафиксируйте все изменения в репозитории!

# %% [markdown]
# Мы будем признательны за обратную связь - любые комментарии, которые вы можете дать по итогам выполнения этого задания.
#
# Например,
#
# - было ли задание понятным по шкале 1..10 (1 - ничего не понятно, 10 - вопросов вообще не было, всё понятно)?
# - было ли задание интересным по шкале 1..10 (1 - скука смертная, 10 - лучшее, что вам пока встречалось на олимпиадах)?
# - что бы вы предложили изменить, чтобы сделает его более интересным?
# - по шкале 1..10 насколько сложным оно было для вас?
# - что было самым трудным в задании?
#
# Авторы наиболее развёрнутых и интересных комментариев получат особенный приз от Лаборатории Касперского!

# %% [markdown]
# Дополнительная информация о кибериммунной разработке
# - https://os.kaspersky.ru/cyber-immune-development/
# - https://github.com/sergey-sobolev/cyberimmune-systems/wiki/%D0%9A%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D0%BC%D0%BC%D1%83%D0%BD%D0%B8%D1%82%D0%B5%D1%82
# - канал в телеграм: https://t.me/learning_cyberimmunity
